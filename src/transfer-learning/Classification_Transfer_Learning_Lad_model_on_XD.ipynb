# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow import keras
from sklearn.model_selection import train_test_split
# from google.colab import drive
# drive.mount("/content/gdrive")
import os
import io
import matplotlib.pyplot as plt
import cv2
# import imageio
#import medmnist
#import ipywidgets
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint
import cv2 as cv
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras import layers, models
import tensorflow as tf
from tensorflow import keras
import ipywidgets
from tensorflow.keras.utils import to_categorical
# Setting seed for reproducibility
SEED = 42
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
np.random.seed(SEED)

# %%
IMG_SIZE = 75
BATCH_SIZE = 256
EPOCHS = 10

MAX_SEQ_LENGTH = 15
NUM_FEATURES = 2048

# %% [markdown]
# # Transfer learning of XD-Violence model on Lad-2000

# %% [markdown]
# ## Destination Dataset

# %%
ROOT = r'C:\Users\Administrator\Downloads\Violence\outputs\xd'

# %%
x_train = np.load(ROOT + '\X_train.npy', mmap_mode="r")
y_train = np.load(ROOT + '\y_train.npy', mmap_mode="c")

x_val = np.load(ROOT + '\X_val.npy', mmap_mode="r")
y_val = np.load(ROOT + '\y_val.npy', mmap_mode="c")

x_test = np.load(ROOT + '\X_test.npy', mmap_mode="r")
y_test = np.load(ROOT + '\y_test.npy', mmap_mode="c")

# %%
def stringtoint(y):
    for i, val in enumerate(y):
        if val == 'Abuse':
            y[i] = 0
        elif val == 'CarAccident':
            y[i] = 1
        elif val == 'Explosion':
            y[i] = 2
        elif val == 'Fighting':
            y[i] = 3
        elif val == 'Riot':
            y[i] = 4
        elif val == 'Shooting':
            y[i] = 5
    return y

# %%
np.unique(y_train)
# Out:
# array(['Abuse', 'CarAccident', 'Explosion', 'Fighting', 'Riot',
#        'Shooting'], dtype='<U11')

# %%
x_train.shape , y_train.shape
# Out:
# ((5728, 15, 75, 75, 3), (5728,))

# %%
y_train = stringtoint(y_train)
y_val = stringtoint(y_val)
y_test = stringtoint(y_test)

# %%
np.unique(y_train)
# Out:
# array(['0', '1', '2', '3', '4', '5'], dtype='<U11')

# %%
y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %%
y_train.shape
# Out:
# (5728, 6)

# %%
x_train = np.moveaxis(x_train, 1, 3)
x_val = np.moveaxis(x_val, 1, 3)
x_test = np.moveaxis(x_test, 1, 3)

# %%
y_train = np.asarray(y_train)

# %%
np.unique(y_train)
# Out:
# array([0., 1.], dtype=float32)

# %%
# x_train, x_rem, y_train, y_rem = train_test_split(x_train, y_train,  train_size=0.7, shuffle = True, random_state=7)

# %%
# x_valid, x_test, y_valid, y_test = train_test_split(x_rem,y_rem, test_size=0.5, shuffle = True, random_state=7)

# %%
# train_data = (np.load(f'{x}_Data\\train_data[0]{y}.npy'), np.load(f'{x}_Data\\train_data[1]{y}.npy'))
# val_data = (np.load(f'{x}_Data\\val_data[0]{y}.npy'), np.load(f'{x}_Data\\val_data[1]{y}.npy'))
# test_data = (np.load(f'{x}_Data\\test_data[0]{y}.npy'), np.load(f'{x}_Data\\test_data[1]{y}.npy'))
# y_train = label_processor(y_train[..., None]).numpy()
# y_val = label_processor(y_val[..., None]).numpy()
# y_test = label_processor(y_test[..., None]).numpy()

# %%
type(y_train[0])
# Out:
# numpy.ndarray

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.test.is_built_with_cuda()
print(tf.version.VERSION)
import sys
sys.version
# Out:
# Num GPUs Available:  1
# 2.5.0
# '3.8.16 (default, Mar  2 2023, 03:18:16) [MSC v.1916 64 bit (AMD64)]'

# %%
# DATA
# DATASET_NAME = "XD-Violence"
BATCH_SIZE = 64
# PATH = '/content/gdrive/MyDrive/data/xd/'
# Extraction_Name = ''
# AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (75, 75, 15, 3)
NUM_CLASSES = 9

# OPTIMIZER
LEARNING_RATE = 0.01
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 5

# TUBELET EMBEDDING
PATCH_SIZE = (8, 8, 8)

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 8
NUM_LAYERS = 8

# %%
# y_train = to_categorical(y_train, 9)
# y_val = to_categorical(y_val, 9)
# y_test = to_categorical(y_test, 9)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (5728, 75, 75, 15, 3) (5728, 6)

# %%
y_train[0]
# Out:
# array([0., 0., 0., 1., 0., 0.], dtype=float32)

# %%
class DataGenerator(keras.utils.Sequence):

    def __init__(self, x_in, y_in, batch_size=BATCH_SIZE, shuffle=True):
        # Initialization
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.x = x_in
        self.y = y_in
        self.datalen = len(y_in)
        self.indexes = np.arange(self.datalen)
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __getitem__(self, index):
        # get batch indexes from shuffled indexes
        batch_indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        x_batch = self.x[batch_indexes]
        y_batch = self.y[batch_indexes]
        return x_batch, y_batch

    def __len__(self):
        # Denotes the number of batches per epoch
        return self.datalen // self.batch_size

    def on_epoch_end(self):
        # Updates indexes after each epoch
        self.indexes = np.arange(self.datalen)
        if self.shuffle:
            np.random.shuffle(self.indexes)

training_generator = DataGenerator(x_train, y_train)
validation_generator = DataGenerator(x_val, y_val)
test_generator = DataGenerator(x_test, y_test)

# %%
train_enquer = tf.keras.utils.OrderedEnqueuer(training_generator)
val_enquer = tf.keras.utils.OrderedEnqueuer(validation_generator)
test_enquer = tf.keras.utils.OrderedEnqueuer(test_generator)

# %%
train_enquer.start(2, 2)
val_enquer.start(2, 2)
test_enquer.start(2, 2)

# %%
np.unique(y_train)
# Out:
# array([0., 1.], dtype=float32)

# %% [markdown]
# #ViVit Model

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

# %%
class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = tf.range(start=0, limit=num_tokens, delta=1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %%
checkpoint_filepath = r'C:\Users\Administrator\Downloads\Violence\outputs\checkpoints\TF-LADonXD.h5'
model_checkpoint = model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                                filepath=checkpoint_filepath,
                                save_weights_only=True,
                                monitor='val_loss',
                                mode='min',
                                save_best_only=True
                                )

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
checkpoint_filepath = r'C:\Users\Administrator\Downloads\Violence\outputs\checkpoints\TF-LADonXD.h5'
checkpoint = model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                                filepath=checkpoint_filepath,
                                save_weights_only=True,
                                monitor='val_loss',
                                mode='min',
                                save_best_only=True
                                )

earlystopping = tf.keras.callbacks.EarlyStopping(
                     monitor="val_loss",
                     min_delta=0.025,
                     patience=5,
                     verbose=0,
                     mode="min",
                     baseline=None,
                     restore_best_weights=False
                 )

values = np.linspace(0.00001,LEARNING_RATE,14)[::-1].astype(np.float32)
boundaries = np.linspace(5, 45,13)[:values.shape[0]-1].astype(np.int32)

scheduler = keras.optimizers.schedules.PiecewiseConstantDecay(
    list(boundaries), list(values))

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler,verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=3, min_lr=0.000001)

callbacks = [checkpoint, lr_scheduler, reduce_lr]

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    input_shape = (75, 75, 15, 3)
    # Get the input layer
    inputs = layers.Input(shape=input_shape)
    # Create patches.
    patches = tubelet_embedder(inputs)
    # Encode patches.
    encoded_patches = positional_encoder(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        # Skip connection
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization and MLP
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=tf.nn.gelu),
                layers.Dense(units=embed_dim, activation=tf.nn.gelu),
            ]
        )(x3)

        # Skip connection
        encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    # Classify outputs.
    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Source Model

# %%
path = r'C:\Users\Administrator\Downloads\Violence\outputs\lad\LAD.h5'

# %%
model = create_vivit_classifier(
            tubelet_embedder=TubeletEmbedding(
                embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
            ),
            positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
        )

# %%
model.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 75, 75, 15,  0
# __________________________________________________________________________________________________
# tubelet_embedding_1 (TubeletEmb (None, 81, 128)      196736      input_2[0][0]
# __________________________________________________________________________________________________
# positional_encoder_1 (Positiona (None, 81, 128)      10368       tubelet_embedding_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 81, 128)      256         positional_encoder_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_8 (MultiHe (None, 81, 128)      66048       layer_normalization_17[0][0]
#                                                                  layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 81, 128)      0           multi_head_attention_8[0][0]
#                                                                  positional_encoder_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 81, 128)      256         add_16[0][0]
# __________________________________________________________________________________________________
# sequential_8 (Sequential)       (None, 81, 128)      131712      layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 81, 128)      0           sequential_8[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 81, 128)      256         add_17[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_9 (MultiHe (None, 81, 128)      66048       layer_normalization_19[0][0]
#                                                                  layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 81, 128)      0           multi_head_attention_9[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, 81, 128)      256         add_18[0][0]
# __________________________________________________________________________________________________
# sequential_9 (Sequential)       (None, 81, 128)      131712      layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 81, 128)      0           sequential_9[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, 81, 128)      256         add_19[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_10 (MultiH (None, 81, 128)      66048       layer_normalization_21[0][0]
#                                                                  layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 81, 128)      0           multi_head_attention_10[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_22 (LayerNo (None, 81, 128)      256         add_20[0][0]
# __________________________________________________________________________________________________
# sequential_10 (Sequential)      (None, 81, 128)      131712      layer_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 81, 128)      0           sequential_10[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_23 (LayerNo (None, 81, 128)      256         add_21[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_11 (MultiH (None, 81, 128)      66048       layer_normalization_23[0][0]
#                                                                  layer_normalization_23[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 81, 128)      0           multi_head_attention_11[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_24 (LayerNo (None, 81, 128)      256         add_22[0][0]
# __________________________________________________________________________________________________
# sequential_11 (Sequential)      (None, 81, 128)      131712      layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 81, 128)      0           sequential_11[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_25 (LayerNo (None, 81, 128)      256         add_23[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_12 (MultiH (None, 81, 128)      66048       layer_normalization_25[0][0]
#                                                                  layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 81, 128)      0           multi_head_attention_12[0][0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# layer_normalization_26 (LayerNo (None, 81, 128)      256         add_24[0][0]
# __________________________________________________________________________________________________
# sequential_12 (Sequential)      (None, 81, 128)      131712      layer_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 81, 128)      0           sequential_12[0][0]
#                                                                  add_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_27 (LayerNo (None, 81, 128)      256         add_25[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_13 (MultiH (None, 81, 128)      66048       layer_normalization_27[0][0]
#                                                                  layer_normalization_27[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 81, 128)      0           multi_head_attention_13[0][0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 81, 128)      256         add_26[0][0]
# __________________________________________________________________________________________________
# sequential_13 (Sequential)      (None, 81, 128)      131712      layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 81, 128)      0           sequential_13[0][0]
#                                                                  add_26[0][0]
# __________________________________________________________________________________________________
# layer_normalization_29 (LayerNo (None, 81, 128)      256         add_27[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_14 (MultiH (None, 81, 128)      66048       layer_normalization_29[0][0]
#                                                                  layer_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 81, 128)      0           multi_head_attention_14[0][0]
#                                                                  add_27[0][0]
# __________________________________________________________________________________________________
# layer_normalization_30 (LayerNo (None, 81, 128)      256         add_28[0][0]
# __________________________________________________________________________________________________
# sequential_14 (Sequential)      (None, 81, 128)      131712      layer_normalization_30[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 81, 128)      0           sequential_14[0][0]
#                                                                  add_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_31 (LayerNo (None, 81, 128)      256         add_29[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_15 (MultiH (None, 81, 128)      66048       layer_normalization_31[0][0]
#                                                                  layer_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 81, 128)      0           multi_head_attention_15[0][0]
#                                                                  add_29[0][0]
# __________________________________________________________________________________________________
# layer_normalization_32 (LayerNo (None, 81, 128)      256         add_30[0][0]
# __________________________________________________________________________________________________
# sequential_15 (Sequential)      (None, 81, 128)      131712      layer_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 81, 128)      0           sequential_15[0][0]
#                                                                  add_30[0][0]
# __________________________________________________________________________________________________
# layer_normalization_33 (LayerNo (None, 81, 128)      256         add_31[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           layer_normalization_33[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 9)            1161        global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 1,794,697
# Trainable params: 1,794,697
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print(len(model.layers))
# Out:
# 54

# %%
def run_experiment():
    model.load_weights(path)
    # # Remove the last layer
    # model.layers.pop()

    # # Create a new model without the last layer
    new_model = keras.Model(inputs=model.input, outputs=model.layers[-2].output)

    new_output = Dense(6, activation='softmax')(new_model.output)
    # # Create the finsal model
    new_model = Model(inputs=new_model.input, outputs=new_output)
    print(len(new_model.layers))
    for layer in new_model.layers[:-2]:
        layer.trainable = False
    print(new_model.summary())
    # Compile the model with the optimizer, loss function
    # and the metrics.
    opt = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    loss_fn = keras.losses.CategoricalCrossentropy(from_logits=False)
    new_model.compile(loss=loss_fn,optimizer=opt,metrics=['accuracy'])
    #model.load_weights(checkpoint_filepath)
    # Train the model.
    history = new_model.fit(training_generator,
                            epochs=EPOCHS,
                            validation_data=(validation_generator),
                            callbacks=[model_checkpoint])
                            # steps_per_epoch= x_train.shape[0] // BATCH_SIZE,
                            # validation_steps= x_val.shape[0] // BATCH_SIZE)

    return new_model, history


model, history = run_experiment()
# Out:
# 54
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 75, 75, 15,  0
# __________________________________________________________________________________________________
# tubelet_embedding_1 (TubeletEmb (None, 81, 128)      196736      input_2[0][0]
# __________________________________________________________________________________________________
# positional_encoder_1 (Positiona (None, 81, 128)      10368       tubelet_embedding_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 81, 128)      256         positional_encoder_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_8 (MultiHe (None, 81, 128)      66048       layer_normalization_17[0][0]
#                                                                  layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 81, 128)      0           multi_head_attention_8[0][0]
#                                                                  positional_encoder_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 81, 128)      256         add_16[0][0]
# __________________________________________________________________________________________________
# sequential_8 (Sequential)       (None, 81, 128)      131712      layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 81, 128)      0           sequential_8[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 81, 128)      256         add_17[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_9 (MultiHe (None, 81, 128)      66048       layer_normalization_19[0][0]
#                                                                  layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 81, 128)      0           multi_head_attention_9[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, 81, 128)      256         add_18[0][0]
# __________________________________________________________________________________________________
# sequential_9 (Sequential)       (None, 81, 128)      131712      layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 81, 128)      0           sequential_9[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, 81, 128)      256         add_19[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_10 (MultiH (None, 81, 128)      66048       layer_normalization_21[0][0]
#                                                                  layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 81, 128)      0           multi_head_attention_10[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_22 (LayerNo (None, 81, 128)      256         add_20[0][0]
# __________________________________________________________________________________________________
# sequential_10 (Sequential)      (None, 81, 128)      131712      layer_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 81, 128)      0           sequential_10[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_23 (LayerNo (None, 81, 128)      256         add_21[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_11 (MultiH (None, 81, 128)      66048       layer_normalization_23[0][0]
#                                                                  layer_normalization_23[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 81, 128)      0           multi_head_attention_11[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_24 (LayerNo (None, 81, 128)      256         add_22[0][0]
# __________________________________________________________________________________________________
# sequential_11 (Sequential)      (None, 81, 128)      131712      layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 81, 128)      0           sequential_11[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_25 (LayerNo (None, 81, 128)      256         add_23[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_12 (MultiH (None, 81, 128)      66048       layer_normalization_25[0][0]
#                                                                  layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 81, 128)      0           multi_head_attention_12[0][0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# layer_normalization_26 (LayerNo (None, 81, 128)      256         add_24[0][0]
# __________________________________________________________________________________________________
# sequential_12 (Sequential)      (None, 81, 128)      131712      layer_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 81, 128)      0           sequential_12[0][0]
#                                                                  add_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_27 (LayerNo (None, 81, 128)      256         add_25[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_13 (MultiH (None, 81, 128)      66048       layer_normalization_27[0][0]
#                                                                  layer_normalization_27[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 81, 128)      0           multi_head_attention_13[0][0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 81, 128)      256         add_26[0][0]
# __________________________________________________________________________________________________
# sequential_13 (Sequential)      (None, 81, 128)      131712      layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 81, 128)      0           sequential_13[0][0]
#                                                                  add_26[0][0]
# __________________________________________________________________________________________________
# layer_normalization_29 (LayerNo (None, 81, 128)      256         add_27[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_14 (MultiH (None, 81, 128)      66048       layer_normalization_29[0][0]
#                                                                  layer_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 81, 128)      0           multi_head_attention_14[0][0]
#                                                                  add_27[0][0]
# __________________________________________________________________________________________________
# layer_normalization_30 (LayerNo (None, 81, 128)      256         add_28[0][0]
# __________________________________________________________________________________________________
# sequential_14 (Sequential)      (None, 81, 128)      131712      layer_normalization_30[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 81, 128)      0           sequential_14[0][0]
#                                                                  add_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_31 (LayerNo (None, 81, 128)      256         add_29[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_15 (MultiH (None, 81, 128)      66048       layer_normalization_31[0][0]
#                                                                  layer_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 81, 128)      0           multi_head_attention_15[0][0]
#                                                                  add_29[0][0]
# __________________________________________________________________________________________________
# layer_normalization_32 (LayerNo (None, 81, 128)      256         add_30[0][0]
# __________________________________________________________________________________________________
# sequential_15 (Sequential)      (None, 81, 128)      131712      layer_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 81, 128)      0           sequential_15[0][0]
#                                                                  add_30[0][0]
# __________________________________________________________________________________________________
# layer_normalization_33 (LayerNo (None, 81, 128)      256         add_31[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           layer_normalization_33[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 6)            774         global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 1,794,310
# Trainable params: 774
# Non-trainable params: 1,793,536
# __________________________________________________________________________________________________
# None
# Epoch 1/5
# 89/89 [==============================] - 145s 1s/step - loss: 0.8558 - accuracy: 0.7101 - val_loss: 0.6078 - val_accuracy: 0.7928
# Epoch 2/5
# 89/89 [==============================] - 33s 368ms/step - loss: 0.5445 - accuracy: 0.8223 - val_loss: 0.5269 - val_accuracy: 0.8183
# Epoch 3/5
# 89/89 [==============================] - 32s 360ms/step - loss: 0.4758 - accuracy: 0.8432 - val_loss: 0.4644 - val_accuracy: 0.8462
# Epoch 4/5
# 89/89 [==============================] - 32s 361ms/step - loss: 0.4323 - accuracy: 0.8597 - val_loss: 0.4465 - val_accuracy: 0.8479
# Epoch 5/5
# 89/89 [==============================] - 32s 363ms/step - loss: 0.4020 - accuracy: 0.8718 - val_loss: 0.4425 - val_accuracy: 0.8429

# %%
! conda install plotly
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import plotly.figure_factory as ff
from sklearn.metrics import f1_score

def eval_model(model,x,y):
#     print(model.evaluate(x.reshape(x.shape+(1,)),y_encoded))
    y_pred = model.predict(x)
    y_pred = np.argmax(y_pred,axis = -1)
    y_numbers = np.argmax(y,axis=-1)
   # f1_score(y_test, y_pred, average='micro')
    #print(f1_score)
    target_names = ['Abuse', 'CarAccident', 'Explosion', 'Fighting', 'Riot', 'Shooting']
    labels = target_names
    tick_marks = np.arange(len(labels))

    print(classification_report(y_numbers, y_pred, target_names=target_names))

    z = tf.math.confusion_matrix(y_numbers,y_pred).numpy().astype(np.int64)
    z = np.around(z.astype('float') / z.sum(axis=1)[:, np.newaxis], decimals=3)

    x = target_names
    y = target_names

    # change each element of z to type string for annotations
    z_text = [[str(y) for y in x] for x in z]

    # set up figure
    fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

    # add title
    fig.update_layout(title_text='<i><b>Confusion matrix</b></i>',
                    #xaxis = dict(title='x'),
                    #yaxis = dict(title='x')
                    )

    # add custom xaxis title
    fig.add_annotation(dict(font=dict(color="black",size=14),
                            x=0.5,
                            y=-0.15,
                            showarrow=False,
                            text="Predicted value",
                            xref="paper",
                            yref="paper"))

    # add custom yaxis title
    fig.add_annotation(dict(font=dict(color="black",size=14),
                            x=-0.35,
                            y=0.5,
                            showarrow=False,
                            text="Real value",
                            textangle=-90,
                            xref="paper",
                            yref="paper"))

    # adjust margins to make room for yaxis title
    fig.update_layout(margin=dict(t=50, l=200))

    # add colorbar
    fig['data'][0]['showscale'] = True
    fig.show()

# %%
! pip install --upgrade nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\administrator\tensorflow_env\lib\site-packages (5.9.0)
# Requirement already satisfied: jupyter-core in c:\users\administrator\tensorflow_env\lib\site-packages (from nbformat) (5.3.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\administrator\tensorflow_env\lib\site-packages (from nbformat) (4.17.3)
# Requirement already satisfied: traitlets>=5.1 in c:\users\administrator\tensorflow_env\lib\site-packages (from nbformat) (5.9.0)
# Requirement already satisfied: fastjsonschema in c:\users\administrator\tensorflow_env\lib\site-packages (from nbformat) (2.17.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\administrator\tensorflow_env\lib\site-packages (from jsonschema>=2.6->nbformat) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\administrator\tensorflow_env\lib\site-packages (from jsonschema>=2.6->nbformat) (5.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\administrator\tensorflow_env\lib\site-packages (from jsonschema>=2.6->nbformat) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\administrator\tensorflow_env\lib\site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: pywin32>=300 in c:\users\administrator\tensorflow_env\lib\site-packages (from jupyter-core->nbformat) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\administrator\tensorflow_env\lib\site-packages (from jupyter-core->nbformat) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\administrator\tensorflow_env\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat) (3.15.0)

# %%
eval_model(model,x_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#        Abuse       0.76      0.83      0.80        42
#  CarAccident       0.81      0.82      0.82       233
#    Explosion       0.90      0.94      0.92       221
#     Fighting       0.88      0.89      0.89       257
#         Riot       0.91      0.78      0.84       246
#     Shooting       0.82      0.87      0.85       229
#
#     accuracy                           0.86      1228
#    macro avg       0.85      0.86      0.85      1228
# weighted avg       0.86      0.86      0.86      1228

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix as cm

def eval_model_f(model,x,y):
#     print(model.evaluate(x.reshape(x.shape+(1,)),y_encoded))
    y_pred = model.predict(x)
    y_pred = np.argmax(y_pred,axis = -1)
    y_numbers = np.argmax(y,axis=-1)

    target_names = ['Abuse', 'CarAccident', 'Explosion', 'Fighting', 'Riot', 'Shooting']
    tick_marks = np.arange(len(target_names))
    print(classification_report(y_numbers, y_pred, target_names=target_names))

    conf = cm(y_numbers,y_pred)

    sns.heatmap(conf,annot=True)
    plt.xticks(tick_marks,target_names,rotation=45)
    plt.yticks(tick_marks,target_names,rotation=0)
    plt.show()

# %%
eval_model_f(model, x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#        Crash       0.71      0.79      0.75       279
#      Destroy       0.82      0.62      0.71       437
#         Drop       0.60      0.89      0.71       453
#     Fighting       0.62      0.68      0.65       490
#         Fire       0.92      0.92      0.92       958
#         Hurt       0.64      0.43      0.52       360
#     Thiefing       0.84      0.76      0.80       495
#     Trampled       0.65      0.72      0.68       461
#     Violence       0.69      0.57      0.62       474
#
#     accuracy                           0.74      4407
#    macro avg       0.72      0.71      0.71      4407
# weighted avg       0.75      0.74      0.73      4407

# %%
encoding

# %%
model = tf.keras.models.load_model(path)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 15, 2048)]   0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 15)]         0
# __________________________________________________________________________________________________
# gru_2 (GRU)                     (None, 15, 128)      836352      input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# gru_3 (GRU)                     (None, 64)           37248       gru_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           gru_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 7)            231         dense_2[0][0]
# ==================================================================================================
# Total params: 875,911
# Trainable params: 875,911
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
new_model = keras.models.Sequential(model.layers[:-1])

# %%
new_model.add(keras.layers.Dense(len(class_vocab), activation="softmax"))

# %%
new_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         multiple                  0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 15, 128)           836352
# _________________________________________________________________
# gru_3 (GRU)                  (None, 64)                37248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# =================================================================
# Total params: 876,010
# Trainable params: 876,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_model.compile(
    loss="sparse_categorical_crossentropy", optimizer="adam",
     metrics = ['accuracy'])

# %%
path
# Out:
# 'Models\\XD_Violence_Main'

# %%
new_model.save("C:\\Users\\Maria\\Violence-Detection\\venv\\Final_Classification\\Models\\LAD_FROM_XD_EX93.17")
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_6_layer_call_and_return_conditional_losses, gru_cell_6_layer_call_fn, gru_cell_7_layer_call_and_return_conditional_losses, gru_cell_7_layer_call_fn, gru_cell_6_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Maria\Violence-Detection\venv\Final_Classification\Models\LAD_FROM_XD_EX93.17\assets
# INFO:tensorflow:Assets written to: C:\Users\Maria\Violence-Detection\venv\Final_Classification\Models\LAD_FROM_XD_EX93.17\assets

# %%
def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend([metric, 'val_'+metric])

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.ylim(None, 1)

plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')
plt.ylim(0, None)
plt.savefig(r'C:\Users\Administrator\Downloads\Violence\outputs\lad\plot.png')

# %%
test_pred = new_model.predict([test_data[0], test_data[1]])
test_pred.shape, test_pred
# Out:
# ((4407, 10),
#  array([[3.50703022e-10, 3.34900847e-06, 3.35044297e-06, ...,
#          9.99960542e-01, 1.45538961e-05, 7.23902031e-06],
#         [2.50789949e-08, 3.42637241e-01, 2.59216729e-04, ...,
#          1.98203847e-02, 8.15141771e-04, 1.89445083e-04],
#         [2.35607193e-11, 5.95811514e-07, 1.51937065e-05, ...,
#          4.85879485e-04, 3.23725566e-02, 9.67097640e-01],
#         ...,
#         [4.76617391e-11, 1.66565590e-02, 6.79557968e-04, ...,
#          9.75974023e-01, 9.33973479e-06, 1.06337552e-06],
#         [5.81201233e-12, 4.04393813e-06, 4.82924179e-07, ...,
#          3.26729532e-05, 9.98594701e-01, 1.25517347e-03],
#         [8.21057469e-13, 9.98156250e-01, 2.38142457e-05, ...,
#          1.41380972e-03, 5.08502524e-07, 6.88980606e-08]], dtype=float32))

# %%
y_pred = []
for i in test_pred:
  for x in np.argsort(i)[::-1]:
    print(f"  {class_vocab[x]}: {i[x] * 100:5.2f}%")
    y_pred.append(class_vocab[x])
    break
# Out:
#   Thiefing: 100.00%
#   Drop: 39.76%
#   Violence: 96.71%
#   Thiefing: 100.00%
#   Trampled: 99.88%
#   Fire: 100.00%
#   Destroy: 99.31%
#   Trampled: 99.20%
#   Fire: 99.90%
#   Drop: 99.95%
#   Destroy: 99.48%
#   Fire: 99.99%
#   Fire: 99.76%
#   Fire: 99.84%
#   Fire: 100.00%
#   Violence: 49.62%
#   Crash: 99.02%
#   Trampled: 99.84%
#   Fire: 99.96%
#   Hurt: 50.31%
#   Violence: 99.11%
#   Fire: 100.00%
#   Trampled: 99.85%
#   Trampled: 99.26%
#   Fire: 100.00%
#   Hurt: 53.89%
#   Hurt: 83.26%
#   Destroy: 99.66%
#   Drop: 99.97%
#   Drop: 99.97%
#   Drop: 99.77%
#   Violence: 99.81%
#   Fire: 100.00%
#   Violence: 79.19%
#   Destroy: 99.89%
#   Crash: 95.01%
#   Violence: 37.33%
#   Fighting: 98.81%
#   Trampled: 60.89%
#   Fighting: 99.53%
#   Hurt: 96.36%
#   Thiefing: 100.00%
#   Destroy: 99.03%
#   Violence: 99.23%
#   Fighting: 96.87%
#   Fire: 100.00%
#   Trampled: 89.61%
#   Fighting: 99.55%
#   Destroy: 93.22%
#   Drop: 99.90%
#   Trampled: 99.91%
#   Drop: 87.86%
#   Thiefing: 100.00%
#   Violence: 64.30%
#   Violence: 98.94%
#   Crash: 87.64%
#   Crash: 99.37%
#   Destroy: 99.94%
#   Violence: 99.22%
#   Trampled: 84.11%
#   Violence: 93.07%
#   Destroy: 99.86%
#   Fighting: 42.44%
#   Hurt: 99.17%
#   Fire: 100.00%
#   Fire: 100.00%
#   Trampled: 51.24%
#   Hurt: 58.77%
#   Trampled: 99.85%
#   Fighting: 96.94%
#   Crash: 70.69%
#   Drop: 99.83%
#   Thiefing: 99.80%
#   Fire: 98.55%
#   Crash: 99.58%
#   Fire: 100.00%
#   Fighting: 98.14%
#   Fighting: 88.99%
#   Violence: 88.68%
#   Fighting: 99.84%
#   Trampled: 98.24%
#   Drop: 99.95%
#   Fire: 100.00%
#   Violence: 99.66%
#   Crash: 94.95%
#   Fire: 100.00%
#   Fighting: 99.70%
#   Fighting: 99.82%
#   Trampled: 99.95%
#   Fire: 99.93%
#   Violence: 99.37%
#   Violence: 98.42%
#   Crash: 93.02%
#   Thiefing: 100.00%
#   Crash: 99.68%
#   Trampled: 99.92%
#   Crash: 99.42%
#   Fire: 99.33%
#   Fighting: 61.68%
#   Trampled: 99.90%
#   Drop: 44.73%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Destroy: 99.97%
#   Fire: 100.00%
#   Fire: 99.55%
#   Fire: 100.00%
#   Trampled: 97.87%
#   Fire: 99.66%
#   Fighting: 91.91%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Destroy: 70.68%
#   Fighting: 97.70%
#   Violence: 95.65%
#   Drop: 99.73%
#   Fighting: 98.02%
#   Drop: 99.94%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 99.97%
#   Destroy: 99.46%
#   Crash: 98.67%
#   Trampled: 59.62%
#   Fire: 100.00%
#   Violence: 97.99%
#   Fighting: 47.93%
#   Fighting: 99.15%
#   Violence: 84.46%
#   Fighting: 99.74%
#   Thiefing: 100.00%
#   Fire: 99.96%
#   Thiefing: 100.00%
#   Drop: 99.04%
#   Fire: 100.00%
#   Thiefing: 99.98%
#   Drop: 99.87%
#   Destroy: 99.95%
#   Thiefing: 100.00%
#   Trampled: 39.51%
#   Destroy: 77.87%
#   Fighting: 98.94%
#   Fighting: 98.94%
#   Fire: 100.00%
#   Fighting: 94.72%
#   Fire: 100.00%
#   Crash: 99.51%
#   Fighting: 99.66%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Drop: 99.67%
#   Fire: 100.00%
#   Destroy: 99.19%
#   Drop: 82.57%
#   Violence: 97.05%
#   Trampled: 99.95%
#   Trampled: 99.72%
#   Fighting: 91.81%
#   Trampled: 99.61%
#   Thiefing: 30.41%
#   Trampled: 99.16%
#   Violence: 99.10%
#   Fighting: 99.40%
#   Destroy: 99.95%
#   Thiefing: 99.48%
#   Drop: 99.35%
#   Violence: 94.75%
#   Fire: 100.00%
#   Fighting: 98.12%
#   Violence: 98.52%
#   Thiefing: 99.99%
#   Drop: 99.94%
#   Fighting: 67.18%
#   Violence: 93.23%
#   Hurt: 85.20%
#   Fire: 100.00%
#   Fighting: 99.89%
#   Drop: 99.97%
#   Fire: 100.00%
#   Fighting: 63.32%
#   Fire: 99.99%
#   Drop: 99.95%
#   Violence: 99.41%
#   Violence: 86.15%
#   Drop: 99.67%
#   Crash: 99.75%
#   Fire: 100.00%
#   Drop: 99.82%
#   Thiefing: 99.98%
#   Destroy: 99.84%
#   Drop: 99.73%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Crash: 99.78%
#   Trampled: 60.93%
#   Trampled: 99.83%
#   Violence: 77.77%
#   Destroy: 96.25%
#   Hurt: 88.83%
#   Fire: 100.00%
#   Violence: 99.12%
#   Fighting: 99.81%
#   Fighting: 99.49%
#   Fighting: 97.01%
#   Fire: 87.14%
#   Fire: 100.00%
#   Trampled: 99.97%
#   Fighting: 99.80%
#   Crash: 92.49%
#   Thiefing: 99.99%
#   Drop: 99.90%
#   Destroy: 99.54%
#   Hurt: 67.39%
#   Destroy: 99.33%
#   Trampled: 97.41%
#   Crash: 99.30%
#   Fighting: 86.39%
#   Destroy: 99.91%
#   Fire: 100.00%
#   Fire: 99.68%
#   Trampled: 95.52%
#   Hurt: 94.70%
#   Fire: 99.74%
#   Trampled: 99.46%
#   Hurt: 99.64%
#   Fire: 99.99%
#   Fire: 99.65%
#   Violence: 92.82%
#   Fire: 100.00%
#   Violence: 97.85%
#   Violence: 90.17%
#   Fighting: 95.84%
#   Destroy: 99.64%
#   Fire: 100.00%
#   Hurt: 95.74%
#   Fire: 99.44%
#   Fire: 99.73%
#   Fire: 99.95%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Violence: 99.18%
#   Fire: 100.00%
#   Destroy: 99.08%
#   Trampled: 99.92%
#   Thiefing: 99.89%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 99.66%
#   Thiefing: 100.00%
#   Trampled: 99.95%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Fire: 99.67%
#   Thiefing: 99.99%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Trampled: 92.39%
#   Drop: 95.27%
#   Fire: 100.00%
#   Fire: 99.66%
#   Violence: 71.33%
#   Hurt: 95.40%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fighting: 98.75%
#   Thiefing: 99.98%
#   Fire: 100.00%
#   Trampled: 99.52%
#   Destroy: 99.12%
#   Violence: 95.49%
#   Fire: 100.00%
#   Fire: 99.61%
#   Fire: 97.43%
#   Destroy: 99.91%
#   Hurt: 57.30%
#   Trampled: 98.45%
#   Trampled: 98.66%
#   Fire: 99.67%
#   Violence: 98.88%
#   Drop: 99.95%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fire: 99.56%
#   Trampled: 99.94%
#   Hurt: 95.85%
#   Fire: 100.00%
#   Fighting: 99.81%
#   Hurt: 45.92%
#   Trampled: 82.04%
#   Violence: 66.56%
#   Drop: 99.88%
#   Thiefing: 100.00%
#   Fighting: 99.44%
#   Trampled: 57.22%
#   Trampled: 83.73%
#   Fire: 100.00%
#   Hurt: 99.51%
#   Destroy: 99.73%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Hurt: 97.09%
#   Fire: 100.00%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Hurt: 91.62%
#   Destroy: 98.93%
#   Trampled: 98.15%
#   Drop: 99.93%
#   Trampled: 84.85%
#   Trampled: 97.94%
#   Drop: 99.29%
#   Fire: 100.00%
#   Trampled: 99.08%
#   Fire: 99.97%
#   Thiefing: 99.98%
#   Violence: 98.69%
#   Destroy: 99.87%
#   Trampled: 99.94%
#   Trampled: 99.91%
#   Drop: 97.20%
#   Violence: 96.76%
#   Fire: 99.67%
#   Trampled: 85.63%
#   Fire: 100.00%
#   Fighting: 99.73%
#   Thiefing: 99.93%
#   Trampled: 98.74%
#   Trampled: 99.95%
#   Drop: 99.95%
#   Thiefing: 99.98%
#   Crash: 99.91%
#   Hurt: 51.31%
#   Fighting: 99.47%
#   Fighting: 90.69%
#   Fire: 100.00%
#   Destroy: 99.64%
#   Fire: 100.00%
#   Hurt: 98.28%
#   Trampled: 72.93%
#   Fire: 100.00%
#   Fighting: 99.56%
#   Hurt: 72.38%
#   Fighting: 97.27%
#   Thiefing: 99.97%
#   Fighting: 96.33%
#   Thiefing: 100.00%
#   Drop: 97.25%
#   Fire: 100.00%
#   Fighting: 98.65%
#   Crash: 98.18%
#   Thiefing: 100.00%
#   Violence: 93.45%
#   Fire: 59.92%
#   Thiefing: 99.86%
#   Fire: 98.94%
#   Fire: 99.73%
#   Thiefing: 52.19%
#   Trampled: 93.94%
#   Drop: 92.35%
#   Fire: 99.99%
#   Destroy: 99.85%
#   Fighting: 63.87%
#   Destroy: 99.97%
#   Violence: 98.78%
#   Violence: 90.77%
#   Hurt: 35.92%
#   Fire: 100.00%
#   Destroy: 99.94%
#   Trampled: 38.73%
#   Drop: 99.85%
#   Fire: 99.66%
#   Hurt: 82.89%
#   Hurt: 75.62%
#   Drop: 99.80%
#   Violence: 99.60%
#   Destroy: 68.23%
#   Hurt: 91.70%
#   Fighting: 27.74%
#   Fire: 100.00%
#   Destroy: 99.91%
#   Destroy: 99.77%
#   Fire: 100.00%
#   Destroy: 88.22%
#   Thiefing: 100.00%
#   Trampled: 99.93%
#   Destroy: 98.93%
#   Destroy: 99.89%
#   Hurt: 92.07%
#   Fighting: 46.49%
#   Fire: 100.00%
#   Drop: 99.96%
#   Thiefing: 100.00%
#   Crash: 86.65%
#   Violence: 98.68%
#   Drop: 99.93%
#   Violence: 91.57%
#   Fighting: 91.16%
#   Crash: 92.26%
#   Fighting: 99.30%
#   Thiefing: 99.92%
#   Hurt: 43.55%
#   Violence: 98.78%
#   Destroy: 99.93%
#   Fighting: 99.80%
#   Destroy: 99.96%
#   Fighting: 97.83%
#   Fire: 99.60%
#   Fire: 99.94%
#   Crash: 99.82%
#   Thiefing: 99.96%
#   Fighting: 99.70%
#   Violence: 62.19%
#   Crash: 91.67%
#   Violence: 70.57%
#   Drop: 99.92%
#   Violence: 98.99%
#   Violence: 92.37%
#   Fighting: 99.76%
#   Trampled: 99.96%
#   Violence: 99.58%
#   Drop: 99.95%
#   Thiefing: 100.00%
#   Fire: 99.96%
#   Fighting: 94.94%
#   Thiefing: 99.98%
#   Fighting: 99.90%
#   Fire: 95.05%
#   Fighting: 99.63%
#   Fighting: 61.46%
#   Fighting: 99.82%
#   Destroy: 99.60%
#   Thiefing: 99.99%
#   Crash: 75.03%
#   Fighting: 97.09%
#   Destroy: 99.98%
#   Crash: 99.77%
#   Thiefing: 99.99%
#   Fighting: 99.80%
#   Thiefing: 100.00%
#   Thiefing: 99.97%
#   Fire: 99.77%
#   Fire: 71.06%
#   Destroy: 95.06%
#   Trampled: 99.89%
#   Destroy: 99.98%
#   Fire: 100.00%
#   Drop: 99.95%
#   Thiefing: 100.00%
#   Drop: 99.80%
#   Fire: 72.43%
#   Fire: 100.00%
#   Fire: 99.88%
#   Thiefing: 99.99%
#   Crash: 99.82%
#   Thiefing: 99.99%
#   Hurt: 41.96%
#   Thiefing: 99.79%
#   Fire: 99.75%
#   Destroy: 53.63%
#   Fighting: 99.75%
#   Crash: 98.41%
#   Drop: 99.90%
#   Crash: 98.75%
#   Drop: 99.60%
#   Crash: 97.85%
#   Fire: 100.00%
#   Drop: 99.97%
#   Trampled: 79.67%
#   Violence: 99.38%
#   Destroy: 99.80%
#   Hurt: 80.22%
#   Destroy: 99.62%
#   Crash: 91.70%
#   Crash: 99.15%
#   Trampled: 99.73%
#   Drop: 99.81%
#   Fire: 99.99%
#   Trampled: 99.76%
#   Trampled: 55.99%
#   Hurt: 98.78%
#   Fire: 99.91%
#   Fire: 100.00%
#   Violence: 53.56%
#   Crash: 99.67%
#   Fighting: 97.44%
#   Fighting: 99.78%
#   Thiefing: 99.99%
#   Violence: 52.10%
#   Fighting: 98.56%
#   Fire: 100.00%
#   Fire: 97.96%
#   Hurt: 53.48%
#   Fighting: 53.77%
#   Drop: 99.91%
#   Hurt: 92.38%
#   Destroy: 99.46%
#   Violence: 99.57%
#   Crash: 98.44%
#   Destroy: 99.93%
#   Trampled: 98.72%
#   Thiefing: 99.98%
#   Fighting: 98.83%
#   Violence: 88.83%
#   Destroy: 98.41%
#   Fighting: 94.04%
#   Violence: 98.47%
#   Hurt: 83.93%
#   Fire: 99.37%
#   Crash: 99.84%
#   Fighting: 99.69%
#   Hurt: 95.44%
#   Fire: 99.98%
#   Trampled: 95.04%
#   Drop: 99.97%
#   Trampled: 99.93%
#   Fighting: 97.99%
#   Violence: 45.69%
#   Trampled: 99.71%
#   Drop: 99.90%
#   Fire: 99.88%
#   Violence: 94.07%
#   Trampled: 99.90%
#   Hurt: 99.67%
#   Drop: 99.96%
#   Fighting: 99.80%
#   Trampled: 99.97%
#   Hurt: 79.67%
#   Fire: 100.00%
#   Trampled: 89.93%
#   Fire: 100.00%
#   Fire: 100.00%
#   Drop: 98.83%
#   Drop: 99.88%
#   Trampled: 99.47%
#   Fire: 100.00%
#   Hurt: 95.50%
#   Thiefing: 80.99%
#   Hurt: 52.09%
#   Fire: 99.83%
#   Fighting: 49.58%
#   Drop: 99.67%
#   Thiefing: 59.83%
#   Destroy: 99.95%
#   Violence: 80.12%
#   Fire: 100.00%
#   Hurt: 97.91%
#   Hurt: 95.16%
#   Thiefing: 100.00%
#   Crash: 99.26%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Drop: 97.13%
#   Fighting: 99.85%
#   Thiefing: 100.00%
#   Fire: 98.04%
#   Hurt: 55.73%
#   Fire: 100.00%
#   Drop: 98.35%
#   Violence: 99.26%
#   Destroy: 99.91%
#   Destroy: 99.87%
#   Trampled: 54.44%
#   Violence: 68.55%
#   Fire: 100.00%
#   Fighting: 99.84%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fighting: 99.76%
#   Violence: 86.63%
#   Violence: 63.53%
#   Violence: 69.68%
#   Hurt: 68.49%
#   Drop: 56.42%
#   Thiefing: 100.00%
#   Violence: 99.27%
#   Destroy: 97.77%
#   Hurt: 81.00%
#   Fire: 100.00%
#   Drop: 98.32%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 99.65%
#   Crash: 99.86%
#   Destroy: 68.12%
#   Fire: 87.48%
#   Fighting: 95.34%
#   Fire: 100.00%
#   Trampled: 97.97%
#   Drop: 99.72%
#   Hurt: 98.43%
#   Fire: 100.00%
#   Crash: 89.25%
#   Trampled: 99.93%
#   Crash: 79.54%
#   Fire: 99.66%
#   Thiefing: 100.00%
#   Trampled: 96.09%
#   Drop: 44.36%
#   Drop: 99.40%
#   Fighting: 56.94%
#   Hurt: 46.74%
#   Fire: 99.66%
#   Violence: 88.83%
#   Destroy: 60.93%
#   Drop: 99.86%
#   Destroy: 99.95%
#   Fire: 100.00%
#   Violence: 99.08%
#   Fire: 99.69%
#   Trampled: 99.73%
#   Trampled: 91.75%
#   Destroy: 97.21%
#   Trampled: 58.20%
#   Violence: 97.84%
#   Fire: 100.00%
#   Destroy: 99.23%
#   Thiefing: 100.00%
#   Drop: 99.82%
#   Fire: 99.52%
#   Violence: 98.94%
#   Fire: 100.00%
#   Destroy: 97.43%
#   Fire: 99.89%
#   Fire: 100.00%
#   Destroy: 99.84%
#   Trampled: 99.89%
#   Violence: 88.77%
#   Fire: 99.88%
#   Trampled: 99.62%
#   Trampled: 82.57%
#   Fighting: 97.96%
#   Trampled: 99.93%
#   Drop: 99.82%
#   Violence: 99.18%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Hurt: 89.23%
#   Fighting: 99.20%
#   Hurt: 89.96%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Violence: 99.65%
#   Fighting: 48.34%
#   Hurt: 48.18%
#   Crash: 99.61%
#   Drop: 99.92%
#   Trampled: 68.96%
#   Fighting: 98.19%
#   Destroy: 99.89%
#   Thiefing: 99.98%
#   Trampled: 61.09%
#   Fire: 99.88%
#   Violence: 97.58%
#   Fire: 99.71%
#   Trampled: 95.26%
#   Thiefing: 100.00%
#   Fighting: 99.84%
#   Fire: 99.88%
#   Fire: 99.89%
#   Trampled: 99.95%
#   Fighting: 95.85%
#   Hurt: 87.33%
#   Thiefing: 100.00%
#   Drop: 99.92%
#   Thiefing: 100.00%
#   Trampled: 99.92%
#   Crash: 93.66%
#   Destroy: 99.93%
#   Crash: 99.12%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Violence: 52.23%
#   Trampled: 89.75%
#   Destroy: 99.98%
#   Trampled: 61.51%
#   Trampled: 99.52%
#   Violence: 88.63%
#   Fire: 100.00%
#   Fire: 100.00%
#   Hurt: 95.69%
#   Fire: 100.00%
#   Hurt: 82.88%
#   Hurt: 97.74%
#   Hurt: 99.35%
#   Fire: 100.00%
#   Destroy: 99.35%
#   Thiefing: 99.99%
#   Thiefing: 99.94%
#   Violence: 99.23%
#   Fire: 70.92%
#   Fire: 100.00%
#   Fire: 99.68%
#   Fire: 71.94%
#   Fighting: 99.07%
#   Fire: 100.00%
#   Violence: 96.43%
#   Violence: 68.31%
#   Destroy: 98.94%
#   Drop: 94.14%
#   Crash: 99.69%
#   Violence: 99.39%
#   Violence: 54.08%
#   Fire: 99.64%
#   Violence: 99.48%
#   Fighting: 80.41%
#   Fighting: 99.87%
#   Fire: 99.91%
#   Violence: 96.73%
#   Violence: 98.79%
#   Fire: 100.00%
#   Violence: 99.15%
#   Destroy: 98.19%
#   Thiefing: 99.98%
#   Trampled: 97.42%
#   Trampled: 99.96%
#   Thiefing: 100.00%
#   Violence: 41.90%
#   Thiefing: 100.00%
#   Violence: 97.05%
#   Trampled: 99.47%
#   Hurt: 41.99%
#   Fighting: 67.03%
#   Crash: 99.75%
#   Fire: 99.93%
#   Hurt: 66.73%
#   Fire: 99.90%
#   Crash: 96.79%
#   Hurt: 97.84%
#   Fire: 99.95%
#   Violence: 98.85%
#   Thiefing: 99.99%
#   Thiefing: 100.00%
#   Drop: 99.91%
#   Trampled: 29.69%
#   Fighting: 44.28%
#   Hurt: 94.80%
#   Destroy: 99.85%
#   Fighting: 78.84%
#   Crash: 99.41%
#   Fighting: 99.83%
#   Crash: 99.83%
#   Fighting: 96.73%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Drop: 99.93%
#   Trampled: 64.94%
#   Violence: 99.83%
#   Fighting: 99.39%
#   Trampled: 99.94%
#   Fighting: 98.65%
#   Fire: 99.85%
#   Fighting: 74.93%
#   Violence: 99.40%
#   Trampled: 99.32%
#   Fighting: 70.48%
#   Violence: 95.20%
#   Drop: 99.93%
#   Crash: 99.91%
#   Hurt: 87.80%
#   Drop: 99.94%
#   Drop: 99.94%
#   Fire: 100.00%
#   Fire: 99.99%
#   Hurt: 89.93%
#   Thiefing: 99.98%
#   Violence: 78.70%
#   Crash: 99.63%
#   Fire: 100.00%
#   Crash: 99.82%
#   Fighting: 99.27%
#   Fire: 100.00%
#   Fighting: 99.22%
#   Drop: 99.93%
#   Drop: 65.49%
#   Crash: 99.40%
#   Fighting: 99.46%
#   Fire: 100.00%
#   Trampled: 99.34%
#   Fighting: 80.87%
#   Drop: 99.73%
#   Thiefing: 99.93%
#   Violence: 96.84%
#   Fighting: 99.20%
#   Fire: 100.00%
#   Trampled: 98.91%
#   Drop: 99.25%
#   Trampled: 95.51%
#   Fire: 100.00%
#   Violence: 97.72%
#   Trampled: 99.56%
#   Trampled: 99.66%
#   Hurt: 33.76%
#   Trampled: 97.08%
#   Trampled: 99.95%
#   Fighting: 99.82%
#   Destroy: 99.65%
#   Drop: 99.85%
#   Destroy: 98.62%
#   Trampled: 99.32%
#   Destroy: 49.15%
#   Crash: 99.05%
#   Destroy: 99.98%
#   Crash: 99.57%
#   Thiefing: 100.00%
#   Crash: 99.68%
#   Hurt: 98.16%
#   Fire: 99.75%
#   Fire: 100.00%
#   Crash: 99.69%
#   Thiefing: 100.00%
#   Fighting: 99.39%
#   Hurt: 98.50%
#   Fighting: 95.78%
#   Trampled: 71.66%
#   Drop: 99.68%
#   Drop: 99.64%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fighting: 85.52%
#   Trampled: 83.50%
#   Fighting: 99.80%
#   Thiefing: 100.00%
#   Drop: 99.97%
#   Destroy: 99.95%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 100.00%
#   Crash: 98.60%
#   Destroy: 99.83%
#   Destroy: 59.67%
#   Fire: 99.64%
#   Fire: 100.00%
#   Trampled: 98.78%
#   Crash: 99.73%
#   Trampled: 99.93%
#   Drop: 99.85%
#   Crash: 97.24%
#   Destroy: 99.74%
#   Fighting: 67.14%
#   Fighting: 46.17%
#   Fire: 100.00%
#   Destroy: 99.97%
#   Fire: 99.84%
#   Fighting: 39.97%
#   Drop: 99.96%
#   Drop: 99.96%
#   Fighting: 98.83%
#   Fire: 100.00%
#   Trampled: 99.81%
#   Crash: 99.00%
#   Trampled: 99.98%
#   Trampled: 99.87%
#   Hurt: 99.08%
#   Fire: 100.00%
#   Fighting: 99.53%
#   Trampled: 99.75%
#   Thiefing: 99.99%
#   Violence: 95.88%
#   Hurt: 98.37%
#   Trampled: 74.16%
#   Drop: 82.03%
#   Destroy: 99.32%
#   Destroy: 99.91%
#   Violence: 98.53%
#   Violence: 98.96%
#   Fighting: 99.06%
#   Crash: 99.51%
#   Trampled: 99.97%
#   Violence: 99.71%
#   Drop: 99.95%
#   Destroy: 99.95%
#   Thiefing: 100.00%
#   Violence: 94.32%
#   Fighting: 44.31%
#   Hurt: 68.30%
#   Fire: 96.58%
#   Crash: 99.62%
#   Trampled: 99.80%
#   Hurt: 82.21%
#   Thiefing: 100.00%
#   Destroy: 95.05%
#   Crash: 98.39%
#   Thiefing: 99.97%
#   Destroy: 99.95%
#   Thiefing: 100.00%
#   Fighting: 90.97%
#   Trampled: 99.81%
#   Fire: 100.00%
#   Fire: 99.66%
#   Drop: 99.96%
#   Drop: 99.61%
#   Drop: 99.89%
#   Drop: 99.94%
#   Fire: 100.00%
#   Trampled: 99.57%
#   Violence: 94.00%
#   Thiefing: 100.00%
#   Fire: 99.88%
#   Drop: 99.90%
#   Drop: 99.87%
#   Fire: 100.00%
#   Drop: 99.75%
#   Destroy: 99.93%
#   Violence: 62.51%
#   Drop: 99.95%
#   Fire: 100.00%
#   Trampled: 66.97%
#   Thiefing: 100.00%
#   Violence: 98.26%
#   Drop: 76.82%
#   Violence: 99.44%
#   Drop: 99.00%
#   Fighting: 93.54%
#   Thiefing: 99.99%
#   Thiefing: 59.02%
#   Thiefing: 99.99%
#   Fighting: 75.48%
#   Drop: 97.53%
#   Fighting: 99.62%
#   Drop: 99.91%
#   Fire: 100.00%
#   Trampled: 99.93%
#   Drop: 99.69%
#   Trampled: 99.08%
#   Violence: 97.50%
#   Fighting: 99.62%
#   Trampled: 99.97%
#   Fire: 99.73%
#   Thiefing: 100.00%
#   Destroy: 99.87%
#   Crash: 99.76%
#   Fire: 100.00%
#   Fire: 99.98%
#   Drop: 99.74%
#   Fighting: 94.75%
#   Thiefing: 100.00%
#   Crash: 99.20%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Fighting: 83.69%
#   Destroy: 59.72%
#   Fire: 100.00%
#   Fighting: 99.89%
#   Destroy: 37.09%
#   Violence: 96.80%
#   Drop: 99.66%
#   Trampled: 99.94%
#   Thiefing: 99.98%
#   Fire: 100.00%
#   Destroy: 99.76%
#   Fighting: 98.15%
#   Destroy: 45.39%
#   Hurt: 83.68%
#   Fighting: 99.63%
#   Destroy: 60.85%
#   Fire: 100.00%
#   Trampled: 83.84%
#   Fighting: 99.82%
#   Destroy: 99.96%
#   Thiefing: 100.00%
#   Violence: 98.37%
#   Thiefing: 100.00%
#   Crash: 98.98%
#   Trampled: 99.89%
#   Fire: 100.00%
#   Fire: 100.00%
#   Violence: 98.58%
#   Drop: 99.51%
#   Fire: 100.00%
#   Fire: 99.82%
#   Fire: 100.00%
#   Fighting: 99.47%
#   Drop: 99.98%
#   Fire: 100.00%
#   Destroy: 99.76%
#   Thiefing: 99.99%
#   Fighting: 92.94%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Hurt: 56.02%
#   Trampled: 93.23%
#   Hurt: 91.91%
#   Drop: 99.68%
#   Fire: 100.00%
#   Violence: 92.74%
#   Violence: 96.60%
#   Destroy: 98.56%
#   Fighting: 63.49%
#   Fire: 98.28%
#   Violence: 60.58%
#   Fire: 100.00%
#   Thiefing: 99.98%
#   Crash: 99.92%
#   Thiefing: 100.00%
#   Crash: 99.75%
#   Fire: 100.00%
#   Fire: 100.00%
#   Hurt: 91.87%
#   Hurt: 35.66%
#   Destroy: 85.71%
#   Drop: 63.19%
#   Fire: 98.96%
#   Fighting: 99.79%
#   Trampled: 98.40%
#   Violence: 93.99%
#   Hurt: 99.69%
#   Fire: 99.94%
#   Drop: 99.97%
#   Fire: 99.99%
#   Trampled: 95.76%
#   Fire: 100.00%
#   Trampled: 99.95%
#   Violence: 97.40%
#   Violence: 93.36%
#   Drop: 99.89%
#   Destroy: 99.51%
#   Destroy: 99.76%
#   Fighting: 99.78%
#   Fire: 100.00%
#   Violence: 48.30%
#   Hurt: 97.68%
#   Fighting: 48.77%
#   Destroy: 99.39%
#   Crash: 99.78%
#   Drop: 99.93%
#   Thiefing: 100.00%
#   Trampled: 99.27%
#   Hurt: 38.72%
#   Violence: 94.60%
#   Crash: 98.48%
#   Hurt: 51.71%
#   Trampled: 99.91%
#   Destroy: 99.76%
#   Fighting: 77.84%
#   Violence: 98.83%
#   Violence: 99.49%
#   Crash: 99.07%
#   Destroy: 99.51%
#   Fire: 100.00%
#   Trampled: 99.14%
#   Thiefing: 100.00%
#   Thiefing: 99.99%
#   Thiefing: 83.30%
#   Destroy: 99.76%
#   Trampled: 98.07%
#   Fighting: 95.70%
#   Thiefing: 100.00%
#   Drop: 99.89%
#   Thiefing: 99.80%
#   Destroy: 61.58%
#   Destroy: 99.66%
#   Fighting: 56.98%
#   Drop: 99.87%
#   Drop: 99.66%
#   Fighting: 99.73%
#   Hurt: 50.65%
#   Fire: 100.00%
#   Hurt: 98.99%
#   Destroy: 97.11%
#   Fire: 100.00%
#   Violence: 88.13%
#   Trampled: 99.95%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Destroy: 99.80%
#   Hurt: 47.72%
#   Fighting: 99.89%
#   Trampled: 68.55%
#   Thiefing: 100.00%
#   Fire: 99.62%
#   Thiefing: 98.28%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Destroy: 99.29%
#   Thiefing: 100.00%
#   Drop: 99.85%
#   Hurt: 98.13%
#   Violence: 98.50%
#   Fighting: 82.49%
#   Trampled: 91.44%
#   Destroy: 98.92%
#   Violence: 69.59%
#   Crash: 98.53%
#   Crash: 98.88%
#   Crash: 59.60%
#   Violence: 90.71%
#   Trampled: 88.05%
#   Thiefing: 100.00%
#   Drop: 99.88%
#   Crash: 88.76%
#   Trampled: 99.52%
#   Fire: 99.88%
#   Trampled: 99.27%
#   Drop: 99.87%
#   Fire: 100.00%
#   Thiefing: 99.37%
#   Thiefing: 100.00%
#   Thiefing: 99.99%
#   Violence: 97.93%
#   Fighting: 97.38%
#   Crash: 99.84%
#   Destroy: 97.70%
#   Trampled: 99.89%
#   Thiefing: 100.00%
#   Fighting: 97.77%
#   Fire: 99.56%
#   Destroy: 99.86%
#   Drop: 99.35%
#   Fighting: 99.71%
#   Destroy: 91.11%
#   Hurt: 98.70%
#   Drop: 96.32%
#   Thiefing: 99.98%
#   Thiefing: 99.99%
#   Drop: 64.84%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Fighting: 70.06%
#   Destroy: 98.29%
#   Fighting: 97.69%
#   Destroy: 86.87%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Hurt: 95.24%
#   Thiefing: 99.99%
#   Thiefing: 99.98%
#   Fighting: 99.38%
#   Trampled: 99.86%
#   Violence: 95.12%
#   Destroy: 99.98%
#   Hurt: 94.76%
#   Trampled: 99.96%
#   Fire: 100.00%
#   Fire: 89.49%
#   Thiefing: 94.00%
#   Drop: 99.95%
#   Destroy: 99.92%
#   Fighting: 99.62%
#   Fire: 99.79%
#   Hurt: 94.82%
#   Drop: 99.37%
#   Fire: 99.98%
#   Destroy: 99.37%
#   Fire: 100.00%
#   Thiefing: 96.02%
#   Violence: 98.77%
#   Fire: 100.00%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Fighting: 99.68%
#   Fire: 100.00%
#   Violence: 98.66%
#   Violence: 98.17%
#   Destroy: 87.53%
#   Destroy: 99.00%
#   Destroy: 99.95%
#   Violence: 98.69%
#   Drop: 93.85%
#   Fire: 99.80%
#   Crash: 82.29%
#   Destroy: 52.32%
#   Fighting: 98.37%
#   Fire: 99.64%
#   Violence: 97.79%
#   Fire: 99.75%
#   Fire: 99.92%
#   Thiefing: 99.99%
#   Destroy: 99.96%
#   Fighting: 96.98%
#   Trampled: 77.68%
#   Hurt: 80.27%
#   Fire: 100.00%
#   Drop: 99.96%
#   Crash: 86.42%
#   Thiefing: 100.00%
#   Drop: 99.53%
#   Hurt: 53.02%
#   Trampled: 99.79%
#   Fire: 100.00%
#   Drop: 98.98%
#   Fire: 99.83%
#   Thiefing: 100.00%
#   Fighting: 72.38%
#   Violence: 99.52%
#   Drop: 99.88%
#   Trampled: 38.43%
#   Fire: 99.82%
#   Drop: 99.95%
#   Drop: 99.76%
#   Destroy: 97.51%
#   Destroy: 99.95%
#   Fighting: 99.41%
#   Fire: 96.59%
#   Violence: 69.48%
#   Trampled: 97.46%
#   Fire: 100.00%
#   Fighting: 99.44%
#   Hurt: 94.07%
#   Drop: 99.50%
#   Drop: 94.76%
#   Hurt: 92.80%
#   Hurt: 78.25%
#   Fire: 100.00%
#   Drop: 95.23%
#   Fire: 100.00%
#   Fighting: 95.32%
#   Fighting: 99.25%
#   Fire: 99.90%
#   Crash: 99.36%
#   Thiefing: 86.19%
#   Hurt: 90.21%
#   Fire: 100.00%
#   Fire: 100.00%
#   Destroy: 99.14%
#   Fire: 100.00%
#   Destroy: 98.53%
#   Drop: 96.09%
#   Drop: 99.82%
#   Fighting: 99.72%
#   Destroy: 99.88%
#   Destroy: 81.07%
#   Thiefing: 99.90%
#   Drop: 99.91%
#   Crash: 99.74%
#   Destroy: 92.81%
#   Violence: 99.06%
#   Violence: 91.20%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 81.48%
#   Violence: 99.15%
#   Fire: 99.81%
#   Destroy: 98.88%
#   Thiefing: 79.41%
#   Crash: 99.57%
#   Hurt: 89.78%
#   Violence: 95.86%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Violence: 86.37%
#   Fire: 100.00%
#   Fire: 99.84%
#   Drop: 99.52%
#   Trampled: 99.88%
#   Thiefing: 100.00%
#   Hurt: 69.46%
#   Fighting: 99.83%
#   Fire: 100.00%
#   Fire: 100.00%
#   Destroy: 99.97%
#   Thiefing: 100.00%
#   Destroy: 98.31%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Violence: 99.66%
#   Violence: 99.06%
#   Destroy: 96.91%
#   Fighting: 99.80%
#   Drop: 99.95%
#   Destroy: 99.87%
#   Fighting: 99.26%
#   Drop: 57.95%
#   Crash: 99.62%
#   Fire: 99.73%
#   Drop: 99.92%
#   Violence: 98.08%
#   Drop: 99.67%
#   Destroy: 98.22%
#   Fighting: 99.74%
#   Fire: 95.73%
#   Trampled: 80.35%
#   Violence: 94.81%
#   Thiefing: 100.00%
#   Trampled: 63.44%
#   Fire: 98.97%
#   Fighting: 99.73%
#   Fire: 100.00%
#   Thiefing: 99.96%
#   Hurt: 99.25%
#   Fire: 99.90%
#   Destroy: 99.88%
#   Violence: 70.58%
#   Fire: 99.76%
#   Destroy: 99.98%
#   Hurt: 46.85%
#   Drop: 99.91%
#   Fire: 100.00%
#   Fire: 99.96%
#   Violence: 97.84%
#   Trampled: 58.82%
#   Trampled: 95.88%
#   Fire: 100.00%
#   Violence: 99.26%
#   Fire: 100.00%
#   Thiefing: 99.93%
#   Violence: 84.81%
#   Fighting: 98.98%
#   Fighting: 97.64%
#   Violence: 93.33%
#   Fire: 100.00%
#   Hurt: 99.45%
#   Fire: 100.00%
#   Trampled: 95.93%
#   Hurt: 97.52%
#   Fire: 100.00%
#   Crash: 99.69%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Crash: 99.77%
#   Hurt: 37.82%
#   Trampled: 99.77%
#   Fighting: 99.79%
#   Violence: 96.03%
#   Thiefing: 100.00%
#   Drop: 99.93%
#   Fighting: 99.41%
#   Fire: 100.00%
#   Crash: 73.23%
#   Trampled: 40.79%
#   Fire: 98.44%
#   Fire: 100.00%
#   Crash: 99.44%
#   Destroy: 99.92%
#   Destroy: 84.33%
#   Fighting: 99.90%
#   Fire: 100.00%
#   Trampled: 99.06%
#   Trampled: 98.96%
#   Thiefing: 100.00%
#   Fighting: 98.98%
#   Thiefing: 99.98%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Violence: 96.87%
#   Violence: 98.43%
#   Drop: 84.05%
#   Drop: 99.73%
#   Hurt: 99.52%
#   Drop: 99.92%
#   Fighting: 98.84%
#   Trampled: 84.24%
#   Destroy: 99.94%
#   Drop: 99.91%
#   Fire: 99.93%
#   Drop: 99.85%
#   Violence: 44.58%
#   Violence: 99.76%
#   Hurt: 88.27%
#   Hurt: 99.46%
#   Fire: 100.00%
#   Violence: 98.52%
#   Fire: 100.00%
#   Fighting: 98.12%
#   Violence: 99.38%
#   Crash: 98.98%
#   Destroy: 61.61%
#   Thiefing: 99.94%
#   Drop: 99.86%
#   Fire: 100.00%
#   Violence: 94.66%
#   Trampled: 99.01%
#   Thiefing: 99.99%
#   Hurt: 77.68%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Hurt: 98.19%
#   Fire: 99.99%
#   Trampled: 99.73%
#   Drop: 99.88%
#   Fire: 99.89%
#   Drop: 99.84%
#   Fighting: 72.84%
#   Violence: 91.03%
#   Crash: 48.08%
#   Violence: 99.76%
#   Thiefing: 100.00%
#   Violence: 97.78%
#   Hurt: 92.34%
#   Violence: 97.73%
#   Thiefing: 100.00%
#   Trampled: 99.37%
#   Fire: 100.00%
#   Fire: 100.00%
#   Destroy: 98.35%
#   Crash: 99.06%
#   Drop: 99.94%
#   Crash: 99.90%
#   Fighting: 99.88%
#   Trampled: 99.98%
#   Hurt: 99.54%
#   Thiefing: 100.00%
#   Trampled: 99.73%
#   Thiefing: 99.82%
#   Drop: 99.53%
#   Destroy: 99.06%
#   Destroy: 99.88%
#   Fire: 99.77%
#   Trampled: 99.96%
#   Drop: 99.95%
#   Fire: 99.92%
#   Violence: 98.73%
#   Fighting: 99.62%
#   Fire: 100.00%
#   Drop: 93.59%
#   Crash: 99.89%
#   Destroy: 99.92%
#   Thiefing: 100.00%
#   Fighting: 99.84%
#   Hurt: 96.38%
#   Drop: 99.88%
#   Fire: 100.00%
#   Fighting: 98.81%
#   Fire: 100.00%
#   Violence: 95.18%
#   Crash: 99.44%
#   Hurt: 98.33%
#   Violence: 65.91%
#   Thiefing: 99.91%
#   Hurt: 39.00%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fighting: 99.14%
#   Thiefing: 100.00%
#   Fire: 99.86%
#   Trampled: 99.13%
#   Fire: 97.21%
#   Trampled: 99.96%
#   Trampled: 99.91%
#   Violence: 74.62%
#   Trampled: 98.26%
#   Fire: 100.00%
#   Trampled: 97.96%
#   Fighting: 91.78%
#   Drop: 99.68%
#   Fighting: 99.72%
#   Fire: 93.03%
#   Destroy: 99.99%
#   Fighting: 95.34%
#   Fighting: 50.78%
#   Destroy: 99.80%
#   Fire: 99.63%
#   Hurt: 35.71%
#   Violence: 98.91%
#   Fire: 99.62%
#   Destroy: 94.63%
#   Fire: 100.00%
#   Thiefing: 98.50%
#   Fighting: 86.33%
#   Crash: 98.90%
#   Trampled: 99.82%
#   Fighting: 70.34%
#   Violence: 99.75%
#   Fire: 98.18%
#   Drop: 99.67%
#   Thiefing: 99.97%
#   Thiefing: 99.97%
#   Trampled: 98.87%
#   Crash: 99.00%
#   Thiefing: 99.99%
#   Violence: 98.32%
#   Drop: 99.53%
#   Drop: 99.15%
#   Violence: 99.43%
#   Trampled: 99.31%
#   Fighting: 99.58%
#   Trampled: 99.96%
#   Fighting: 99.78%
#   Destroy: 97.39%
#   Violence: 99.50%
#   Thiefing: 99.99%
#   Fire: 99.30%
#   Fighting: 75.34%
#   Trampled: 99.63%
#   Hurt: 98.20%
#   Fighting: 99.74%
#   Thiefing: 100.00%
#   Destroy: 99.78%
#   Drop: 99.36%
#   Trampled: 99.98%
#   Trampled: 99.29%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Hurt: 88.55%
#   Hurt: 99.28%
#   Trampled: 99.81%
#   Fire: 99.87%
#   Fighting: 80.25%
#   Thiefing: 100.00%
#   Drop: 99.78%
#   Trampled: 99.95%
#   Crash: 99.06%
#   Thiefing: 99.99%
#   Drop: 99.95%
#   Destroy: 99.13%
#   Crash: 84.99%
#   Drop: 99.90%
#   Hurt: 47.12%
#   Crash: 96.34%
#   Trampled: 99.57%
#   Fire: 100.00%
#   Crash: 99.51%
#   Trampled: 99.94%
#   Crash: 99.40%
#   Fighting: 99.19%
#   Fire: 100.00%
#   Fighting: 99.70%
#   Fire: 100.00%
#   Trampled: 91.34%
#   Fighting: 99.41%
#   Crash: 99.82%
#   Fire: 100.00%
#   Trampled: 97.26%
#   Trampled: 99.31%
#   Hurt: 65.56%
#   Destroy: 99.95%
#   Fire: 100.00%
#   Violence: 93.70%
#   Drop: 99.91%
#   Destroy: 99.90%
#   Thiefing: 100.00%
#   Violence: 98.99%
#   Fire: 99.28%
#   Hurt: 98.37%
#   Fighting: 99.62%
#   Fire: 100.00%
#   Drop: 99.96%
#   Fighting: 99.77%
#   Destroy: 52.46%
#   Drop: 99.95%
#   Fire: 99.93%
#   Destroy: 92.93%
#   Crash: 99.64%
#   Violence: 98.48%
#   Trampled: 87.03%
#   Thiefing: 99.61%
#   Fire: 99.04%
#   Hurt: 96.84%
#   Thiefing: 100.00%
#   Hurt: 32.87%
#   Fire: 99.48%
#   Crash: 99.73%
#   Violence: 99.26%
#   Fighting: 97.61%
#   Thiefing: 100.00%
#   Destroy: 82.86%
#   Violence: 99.50%
#   Fighting: 52.98%
#   Fire: 99.90%
#   Hurt: 97.90%
#   Drop: 99.76%
#   Crash: 99.30%
#   Fire: 100.00%
#   Violence: 97.24%
#   Hurt: 77.33%
#   Thiefing: 100.00%
#   Violence: 99.46%
#   Fighting: 97.54%
#   Destroy: 92.93%
#   Violence: 98.75%
#   Fighting: 98.99%
#   Fighting: 80.22%
#   Violence: 85.28%
#   Trampled: 99.73%
#   Violence: 33.63%
#   Thiefing: 99.99%
#   Violence: 57.50%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fighting: 94.96%
#   Destroy: 99.61%
#   Fire: 100.00%
#   Drop: 99.94%
#   Destroy: 99.34%
#   Destroy: 99.88%
#   Trampled: 99.78%
#   Destroy: 93.59%
#   Fighting: 93.38%
#   Destroy: 99.89%
#   Drop: 99.91%
#   Violence: 99.31%
#   Fire: 100.00%
#   Thiefing: 99.80%
#   Trampled: 89.97%
#   Trampled: 99.93%
#   Fire: 99.65%
#   Drop: 99.95%
#   Drop: 99.92%
#   Fighting: 99.82%
#   Fire: 100.00%
#   Fire: 99.65%
#   Drop: 99.97%
#   Fire: 100.00%
#   Fighting: 96.60%
#   Trampled: 99.96%
#   Violence: 99.17%
#   Fire: 100.00%
#   Crash: 99.16%
#   Trampled: 99.36%
#   Fighting: 99.35%
#   Fire: 99.96%
#   Fire: 100.00%
#   Trampled: 99.90%
#   Drop: 99.84%
#   Fighting: 99.27%
#   Fire: 100.00%
#   Fire: 99.44%
#   Violence: 99.35%
#   Crash: 80.46%
#   Fighting: 91.12%
#   Thiefing: 99.86%
#   Drop: 99.91%
#   Violence: 99.34%
#   Trampled: 88.76%
#   Fighting: 99.28%
#   Fire: 100.00%
#   Crash: 99.62%
#   Fighting: 90.62%
#   Trampled: 99.94%
#   Violence: 99.13%
#   Fire: 99.99%
#   Trampled: 99.93%
#   Drop: 99.70%
#   Fire: 100.00%
#   Crash: 99.45%
#   Drop: 99.90%
#   Crash: 85.19%
#   Drop: 99.79%
#   Destroy: 98.99%
#   Fire: 100.00%
#   Destroy: 99.49%
#   Fighting: 49.64%
#   Fire: 100.00%
#   Hurt: 92.81%
#   Trampled: 51.82%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Trampled: 49.28%
#   Crash: 98.66%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Drop: 95.78%
#   Violence: 98.91%
#   Violence: 98.75%
#   Fire: 99.95%
#   Fire: 100.00%
#   Fire: 100.00%
#   Drop: 94.15%
#   Fire: 100.00%
#   Fire: 100.00%
#   Drop: 99.35%
#   Hurt: 96.41%
#   Fire: 99.91%
#   Thiefing: 100.00%
#   Thiefing: 71.80%
#   Drop: 99.52%
#   Fire: 100.00%
#   Drop: 93.72%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Trampled: 47.01%
#   Destroy: 30.03%
#   Fire: 100.00%
#   Fire: 99.00%
#   Thiefing: 99.98%
#   Fire: 100.00%
#   Crash: 99.86%
#   Drop: 99.62%
#   Thiefing: 99.99%
#   Destroy: 99.91%
#   Thiefing: 97.03%
#   Thiefing: 99.99%
#   Hurt: 53.87%
#   Violence: 98.32%
#   Violence: 95.02%
#   Destroy: 49.96%
#   Violence: 99.41%
#   Trampled: 99.95%
#   Hurt: 41.54%
#   Fire: 98.94%
#   Fighting: 97.19%
#   Trampled: 99.54%
#   Thiefing: 99.97%
#   Crash: 98.89%
#   Fire: 99.99%
#   Fighting: 99.83%
#   Drop: 99.88%
#   Thiefing: 100.00%
#   Hurt: 92.79%
#   Drop: 99.96%
#   Crash: 99.66%
#   Destroy: 99.86%
#   Destroy: 99.98%
#   Trampled: 68.64%
#   Destroy: 99.86%
#   Fighting: 99.57%
#   Fighting: 99.90%
#   Fighting: 99.61%
#   Violence: 78.07%
#   Violence: 84.73%
#   Violence: 98.41%
#   Fire: 100.00%
#   Destroy: 90.44%
#   Trampled: 67.95%
#   Trampled: 98.39%
#   Crash: 99.32%
#   Thiefing: 100.00%
#   Fire: 99.89%
#   Drop: 99.92%
#   Trampled: 99.85%
#   Crash: 98.80%
#   Fire: 99.93%
#   Thiefing: 100.00%
#   Hurt: 52.65%
#   Fighting: 99.21%
#   Violence: 93.89%
#   Fire: 99.74%
#   Destroy: 99.87%
#   Trampled: 99.89%
#   Fighting: 99.45%
#   Fire: 99.90%
#   Destroy: 99.94%
#   Violence: 99.37%
#   Violence: 97.90%
#   Thiefing: 99.99%
#   Thiefing: 100.00%
#   Drop: 99.73%
#   Drop: 99.97%
#   Fire: 100.00%
#   Violence: 73.26%
#   Trampled: 99.91%
#   Drop: 76.13%
#   Trampled: 84.19%
#   Destroy: 99.66%
#   Hurt: 99.04%
#   Thiefing: 99.99%
#   Drop: 99.73%
#   Destroy: 99.91%
#   Fire: 100.00%
#   Crash: 99.65%
#   Fire: 100.00%
#   Trampled: 81.66%
#   Destroy: 99.27%
#   Fighting: 60.42%
#   Crash: 96.98%
#   Hurt: 95.33%
#   Fighting: 97.76%
#   Drop: 99.96%
#   Hurt: 91.25%
#   Destroy: 99.95%
#   Hurt: 76.55%
#   Hurt: 68.48%
#   Destroy: 98.99%
#   Drop: 99.95%
#   Destroy: 99.81%
#   Violence: 99.08%
#   Fighting: 99.41%
#   Fire: 99.75%
#   Thiefing: 100.00%
#   Violence: 98.52%
#   Thiefing: 100.00%
#   Trampled: 38.78%
#   Violence: 63.57%
#   Hurt: 90.56%
#   Destroy: 36.49%
#   Fire: 100.00%
#   Crash: 98.24%
#   Destroy: 85.15%
#   Destroy: 99.90%
#   Fighting: 99.83%
#   Drop: 99.96%
#   Violence: 94.66%
#   Thiefing: 99.96%
#   Violence: 97.81%
#   Hurt: 90.04%
#   Fire: 99.84%
#   Thiefing: 99.99%
#   Thiefing: 100.00%
#   Drop: 99.82%
#   Fighting: 98.75%
#   Thiefing: 100.00%
#   Fire: 99.85%
#   Fire: 99.51%
#   Trampled: 99.91%
#   Fire: 100.00%
#   Fire: 99.94%
#   Fighting: 99.20%
#   Fire: 100.00%
#   Fighting: 99.23%
#   Destroy: 80.06%
#   Destroy: 99.93%
#   Drop: 99.68%
#   Violence: 89.87%
#   Drop: 99.78%
#   Hurt: 50.12%
#   Destroy: 96.23%
#   Drop: 98.19%
#   Thiefing: 100.00%
#   Violence: 97.54%
#   Thiefing: 100.00%
#   Fire: 99.78%
#   Hurt: 96.22%
#   Destroy: 99.90%
#   Fire: 100.00%
#   Crash: 99.71%
#   Trampled: 99.89%
#   Trampled: 77.87%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Destroy: 58.03%
#   Trampled: 90.12%
#   Thiefing: 100.00%
#   Fire: 99.93%
#   Destroy: 99.90%
#   Trampled: 88.26%
#   Destroy: 85.30%
#   Fire: 97.19%
#   Trampled: 89.66%
#   Fighting: 88.91%
#   Crash: 97.66%
#   Fighting: 99.29%
#   Fire: 99.84%
#   Violence: 50.75%
#   Fire: 99.69%
#   Violence: 99.48%
#   Fire: 99.81%
#   Fighting: 99.82%
#   Thiefing: 100.00%
#   Trampled: 99.29%
#   Violence: 97.47%
#   Drop: 99.27%
#   Crash: 99.83%
#   Destroy: 96.86%
#   Trampled: 83.75%
#   Thiefing: 99.97%
#   Destroy: 99.88%
#   Trampled: 99.94%
#   Thiefing: 99.99%
#   Drop: 99.90%
#   Violence: 68.69%
#   Hurt: 96.47%
#   Trampled: 99.74%
#   Fighting: 99.78%
#   Destroy: 99.97%
#   Hurt: 53.91%
#   Thiefing: 100.00%
#   Fire: 99.85%
#   Trampled: 99.98%
#   Destroy: 99.95%
#   Violence: 92.15%
#   Violence: 99.56%
#   Destroy: 99.98%
#   Fire: 100.00%
#   Crash: 99.77%
#   Violence: 61.31%
#   Hurt: 76.20%
#   Trampled: 79.79%
#   Trampled: 90.27%
#   Crash: 99.45%
#   Trampled: 99.42%
#   Fighting: 54.51%
#   Destroy: 91.02%
#   Drop: 99.95%
#   Fire: 100.00%
#   Violence: 99.74%
#   Drop: 99.91%
#   Drop: 90.37%
#   Hurt: 98.81%
#   Fighting: 99.85%
#   Trampled: 99.81%
#   Fire: 100.00%
#   Fire: 99.93%
#   Fire: 100.00%
#   Drop: 99.92%
#   Fighting: 88.53%
#   Thiefing: 99.99%
#   Drop: 99.92%
#   Thiefing: 99.62%
#   Fire: 99.85%
#   Violence: 64.43%
#   Fire: 99.90%
#   Thiefing: 99.17%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Trampled: 77.67%
#   Trampled: 99.41%
#   Fire: 100.00%
#   Fire: 99.97%
#   Drop: 98.70%
#   Trampled: 60.82%
#   Destroy: 98.78%
#   Hurt: 90.88%
#   Fire: 100.00%
#   Fire: 100.00%
#   Destroy: 99.99%
#   Crash: 99.43%
#   Crash: 98.46%
#   Drop: 99.94%
#   Hurt: 98.46%
#   Destroy: 99.95%
#   Fire: 99.55%
#   Fire: 99.72%
#   Violence: 99.30%
#   Drop: 99.16%
#   Fire: 100.00%
#   Fighting: 99.82%
#   Crash: 99.75%
#   Violence: 94.88%
#   Hurt: 45.29%
#   Violence: 97.84%
#   Destroy: 92.65%
#   Fire: 100.00%
#   Trampled: 99.98%
#   Thiefing: 100.00%
#   Thiefing: 99.99%
#   Destroy: 99.95%
#   Drop: 99.51%
#   Drop: 99.87%
#   Fire: 99.90%
#   Fire: 99.85%
#   Thiefing: 99.99%
#   Violence: 97.20%
#   Fire: 99.88%
#   Fire: 100.00%
#   Fighting: 99.80%
#   Fire: 100.00%
#   Hurt: 54.42%
#   Fire: 73.70%
#   Thiefing: 100.00%
#   Trampled: 99.90%
#   Fire: 100.00%
#   Fire: 99.97%
#   Fire: 100.00%
#   Trampled: 99.88%
#   Fire: 99.95%
#   Trampled: 53.60%
#   Fire: 99.85%
#   Drop: 99.94%
#   Fire: 99.85%
#   Thiefing: 99.98%
#   Fire: 100.00%
#   Drop: 98.13%
#   Fighting: 99.59%
#   Crash: 99.23%
#   Fighting: 95.46%
#   Fire: 99.99%
#   Fire: 100.00%
#   Fire: 100.00%
#   Hurt: 45.36%
#   Hurt: 98.91%
#   Fighting: 95.44%
#   Destroy: 99.93%
#   Trampled: 34.45%
#   Destroy: 99.81%
#   Hurt: 99.53%
#   Fire: 99.65%
#   Crash: 99.72%
#   Fire: 99.65%
#   Drop: 99.87%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 99.70%
#   Fighting: 94.91%
#   Fire: 100.00%
#   Drop: 99.66%
#   Violence: 99.36%
#   Fire: 99.80%
#   Hurt: 74.91%
#   Thiefing: 100.00%
#   Drop: 70.81%
#   Drop: 99.70%
#   Fighting: 97.41%
#   Trampled: 87.34%
#   Crash: 99.07%
#   Drop: 99.59%
#   Fire: 100.00%
#   Hurt: 78.96%
#   Fire: 99.73%
#   Fire: 100.00%
#   Trampled: 99.97%
#   Fire: 99.86%
#   Trampled: 99.92%
#   Fighting: 98.07%
#   Thiefing: 99.97%
#   Trampled: 99.93%
#   Drop: 99.76%
#   Drop: 98.78%
#   Drop: 99.07%
#   Violence: 99.16%
#   Trampled: 74.12%
#   Violence: 61.90%
#   Trampled: 99.94%
#   Crash: 99.69%
#   Destroy: 99.70%
#   Crash: 99.75%
#   Drop: 98.61%
#   Trampled: 63.70%
#   Violence: 99.57%
#   Drop: 99.73%
#   Crash: 74.40%
#   Fire: 99.40%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Violence: 99.19%
#   Crash: 77.77%
#   Trampled: 89.78%
#   Fire: 99.87%
#   Fighting: 99.62%
#   Hurt: 99.34%
#   Fighting: 99.70%
#   Fighting: 69.89%
#   Fighting: 99.77%
#   Fire: 100.00%
#   Trampled: 96.85%
#   Trampled: 96.41%
#   Drop: 99.96%
#   Fighting: 99.42%
#   Thiefing: 100.00%
#   Fighting: 82.72%
#   Destroy: 99.89%
#   Destroy: 99.98%
#   Fire: 99.88%
#   Crash: 99.14%
#   Fighting: 99.65%
#   Drop: 99.95%
#   Destroy: 99.94%
#   Hurt: 58.70%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Fire: 99.99%
#   Trampled: 98.00%
#   Fire: 100.00%
#   Destroy: 99.83%
#   Trampled: 46.51%
#   Trampled: 40.33%
#   Thiefing: 99.94%
#   Fire: 100.00%
#   Trampled: 99.97%
#   Fire: 99.65%
#   Hurt: 55.81%
#   Violence: 91.22%
#   Fire: 99.60%
#   Fighting: 99.10%
#   Fighting: 99.42%
#   Fire: 100.00%
#   Fighting: 95.91%
#   Crash: 99.87%
#   Fighting: 99.01%
#   Destroy: 99.97%
#   Trampled: 99.88%
#   Drop: 99.85%
#   Fighting: 99.63%
#   Thiefing: 99.98%
#   Destroy: 63.60%
#   Trampled: 83.17%
#   Thiefing: 99.99%
#   Fire: 99.92%
#   Violence: 98.84%
#   Violence: 99.00%
#   Thiefing: 99.98%
#   Violence: 69.10%
#   Fire: 100.00%
#   Violence: 97.73%
#   Drop: 99.65%
#   Thiefing: 100.00%
#   Destroy: 95.57%
#   Thiefing: 99.99%
#   Thiefing: 99.92%
#   Crash: 99.20%
#   Fire: 100.00%
#   Destroy: 99.96%
#   Violence: 61.13%
#   Destroy: 99.95%
#   Fighting: 98.40%
#   Fire: 100.00%
#   Fighting: 99.75%
#   Thiefing: 99.96%
#   Drop: 99.92%
#   Destroy: 99.92%
#   Trampled: 99.95%
#   Fire: 100.00%
#   Drop: 99.96%
#   Fighting: 52.91%
#   Fire: 100.00%
#   Fire: 99.81%
#   Fire: 100.00%
#   Fighting: 99.73%
#   Fighting: 91.36%
#   Drop: 95.34%
#   Trampled: 85.25%
#   Drop: 99.97%
#   Hurt: 99.50%
#   Drop: 99.74%
#   Violence: 89.07%
#   Fire: 64.93%
#   Fighting: 99.80%
#   Hurt: 82.58%
#   Fighting: 95.37%
#   Trampled: 99.90%
#   Drop: 94.72%
#   Violence: 94.15%
#   Fire: 99.81%
#   Fighting: 94.13%
#   Thiefing: 100.00%
#   Destroy: 99.98%
#   Destroy: 27.67%
#   Trampled: 99.88%
#   Crash: 99.57%
#   Destroy: 99.94%
#   Trampled: 91.93%
#   Fighting: 99.50%
#   Fire: 100.00%
#   Drop: 98.86%
#   Thiefing: 99.99%
#   Violence: 67.80%
#   Fire: 98.10%
#   Thiefing: 99.99%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Fire: 100.00%
#   Trampled: 99.96%
#   Drop: 99.90%
#   Drop: 82.50%
#   Destroy: 99.97%
#   Trampled: 98.80%
#   Drop: 99.95%
#   Fire: 99.65%
#   Crash: 99.81%
#   Hurt: 90.03%
#   Trampled: 53.17%
#   Violence: 99.36%
#   Thiefing: 100.00%
#   Fighting: 80.74%
#   Thiefing: 99.99%
#   Drop: 99.92%
#   Fire: 100.00%
#   Fighting: 99.41%
#   Trampled: 99.63%
#   Hurt: 42.08%
#   Thiefing: 99.90%
#   Fighting: 96.12%
#   Fighting: 95.83%
#   Destroy: 99.72%
#   Violence: 99.18%
#   Fighting: 39.28%
#   Destroy: 76.32%
#   Hurt: 57.87%
#   Drop: 99.82%
#   Drop: 99.97%
#   Fire: 99.87%
#   Fire: 100.00%
#   Fighting: 99.27%
#   Hurt: 58.75%
#   Thiefing: 99.98%
#   Fire: 100.00%
#   Crash: 95.35%
#   Fighting: 39.65%
#   Destroy: 99.92%
#   Drop: 99.65%
#   Thiefing: 97.85%
#   Fire: 100.00%
#   Drop: 99.84%
#   Trampled: 99.98%
#   Destroy: 71.56%
#   Destroy: 99.98%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Fire: 100.00%
#   Hurt: 96.64%
#   Violence: 96.93%
#   Fighting: 99.45%
#   Fighting: 88.82%
#   Violence: 26.17%
#   Fire: 99.97%
#   Drop: 99.56%
#   Fire: 100.00%
#   Trampled: 98.76%
#   Fighting: 99.41%
#   Destroy: 98.89%
#   Trampled: 99.95%
#   Drop: 99.67%
#   Fire: 100.00%
#   Fighting: 91.22%
#   Fighting: 85.61%
#   Thiefing: 100.00%
#   Hurt: 99.09%
#   Hurt: 72.37%
#   Violence: 98.49%
#   Fighting: 99.44%
#   Trampled: 99.80%
#   Crash: 98.89%
#   Fire: 99.19%
#   Destroy: 97.72%
#   Trampled: 98.88%
#   Thiefing: 99.97%
#   Trampled: 99.77%
#   Fire: 100.00%
#   Fighting: 96.32%
#   Crash: 99.15%
#   Fire: 99.85%
#   Thiefing: 99.87%
#   Trampled: 89.28%
#   Violence: 99.66%
#   Destroy: 99.94%
#   Crash: 99.06%
#   Fire: 99.90%
#   Fighting: 99.93%
#   Hurt: 99.11%
#   Trampled: 84.04%
#   Thiefing: 100.00%
#   Trampled: 96.60%
#   Trampled: 99.87%
#   Violence: 92.08%
#   Fire: 98.54%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Destroy: 99.98%
#   Fighting: 99.65%
#   Trampled: 99.95%
#   Fire: 99.65%
#   Violence: 93.62%
#   Fire: 100.00%
#   Trampled: 99.97%
#   Fire: 100.00%
#   Fire: 99.89%
#   Thiefing: 100.00%
#   Thiefing: 99.99%
#   Hurt: 99.31%
#   Fire: 100.00%
#   Trampled: 77.68%
#   Fighting: 82.64%
#   Fire: 99.52%
#   Thiefing: 99.99%
#   Hurt: 90.64%
#   Violence: 95.16%
#   Crash: 79.51%
#   Hurt: 45.94%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fighting: 50.83%
#   Fire: 99.90%
#   Fire: 99.87%
#   Fighting: 92.40%
#   Fighting: 99.17%
#   Fire: 98.87%
#   Violence: 98.03%
#   Drop: 98.24%
#   Trampled: 98.72%
#   Fire: 100.00%
#   Destroy: 99.98%
#   Violence: 99.05%
#   Destroy: 65.26%
#   Destroy: 99.95%
#   Drop: 99.96%
#   Fire: 100.00%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Thiefing: 99.98%
#   Fighting: 99.81%
#   Fighting: 98.31%
#   Thiefing: 99.98%
#   Crash: 99.71%
#   Fire: 99.67%
#   Fighting: 99.81%
#   Destroy: 99.90%
#   Trampled: 99.50%
#   Fighting: 99.84%
#   Fighting: 99.68%
#   Destroy: 55.80%
#   Thiefing: 99.99%
#   Fighting: 84.66%
#   Fire: 99.70%
#   Crash: 99.83%
#   Crash: 74.13%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Destroy: 81.23%
#   Destroy: 99.92%
#   Destroy: 99.93%
#   Fire: 99.07%
#   Drop: 99.72%
#   Hurt: 97.01%
#   Trampled: 99.11%
#   Fighting: 98.79%
#   Hurt: 90.88%
#   Hurt: 98.43%
#   Destroy: 99.98%
#   Drop: 99.64%
#   Drop: 99.86%
#   Drop: 94.12%
#   Trampled: 96.79%
#   Violence: 99.14%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Hurt: 97.90%
#   Trampled: 99.47%
#   Destroy: 95.47%
#   Fighting: 44.48%
#   Fighting: 99.75%
#   Destroy: 65.29%
#   Fighting: 46.18%
#   Violence: 90.59%
#   Drop: 99.62%
#   Crash: 99.86%
#   Destroy: 99.93%
#   Destroy: 54.96%
#   Fire: 99.79%
#   Hurt: 65.87%
#   Thiefing: 100.00%
#   Trampled: 97.97%
#   Trampled: 96.45%
#   Destroy: 99.92%
#   Fire: 100.00%
#   Thiefing: 89.08%
#   Fire: 100.00%
#   Destroy: 99.94%
#   Fire: 100.00%
#   Destroy: 99.86%
#   Trampled: 99.36%
#   Fighting: 99.21%
#   Fire: 91.27%
#   Fire: 100.00%
#   Violence: 99.11%
#   Fighting: 99.80%
#   Thiefing: 99.98%
#   Thiefing: 100.00%
#   Fighting: 99.67%
#   Violence: 94.77%
#   Drop: 99.62%
#   Fire: 100.00%
#   Trampled: 94.31%
#   Crash: 99.60%
#   Fire: 100.00%
#   Violence: 98.51%
#   Violence: 69.10%
#   Drop: 99.55%
#   Fighting: 99.82%
#   Fire: 100.00%
#   Fighting: 97.05%
#   Destroy: 99.98%
#   Fire: 100.00%
#   Violence: 88.63%
#   Fire: 99.68%
#   Violence: 95.19%
#   Thiefing: 100.00%
#   Fire: 98.59%
#   Fire: 100.00%
#   Fire: 99.98%
#   Fire: 99.94%
#   Thiefing: 100.00%
#   Thiefing: 98.98%
#   Drop: 99.93%
#   Fire: 99.73%
#   Thiefing: 100.00%
#   Hurt: 98.88%
#   Fire: 100.00%
#   Destroy: 95.67%
#   Violence: 99.59%
#   Trampled: 93.74%
#   Fire: 100.00%
#   Fire: 100.00%
#   Crash: 99.76%
#   Fire: 99.83%
#   Thiefing: 99.99%
#   Drop: 99.96%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Crash: 98.35%
#   Crash: 49.70%
#   Thiefing: 100.00%
#   Fighting: 99.59%
#   Drop: 99.26%
#   Thiefing: 100.00%
#   Drop: 99.94%
#   Fire: 100.00%
#   Trampled: 99.93%
#   Thiefing: 100.00%
#   Fire: 35.89%
#   Crash: 62.14%
#   Fire: 99.77%
#   Hurt: 53.60%
#   Violence: 85.93%
#   Destroy: 99.60%
#   Drop: 90.69%
#   Drop: 99.94%
#   Trampled: 99.93%
#   Drop: 99.65%
#   Violence: 51.83%
#   Fighting: 99.24%
#   Violence: 63.47%
#   Hurt: 64.48%
#   Destroy: 99.92%
#   Drop: 99.98%
#   Violence: 95.04%
#   Violence: 99.70%
#   Fire: 100.00%
#   Destroy: 97.02%
#   Destroy: 91.95%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Violence: 98.68%
#   Trampled: 99.64%
#   Trampled: 99.75%
#   Fire: 99.64%
#   Drop: 99.69%
#   Drop: 99.96%
#   Violence: 98.89%
#   Crash: 99.70%
#   Destroy: 99.90%
#   Fire: 99.96%
#   Drop: 99.91%
#   Fighting: 99.41%
#   Trampled: 99.98%
#   Trampled: 54.37%
#   Fighting: 99.32%
#   Fighting: 46.77%
#   Violence: 99.47%
#   Trampled: 95.95%
#   Thiefing: 99.98%
#   Trampled: 99.41%
#   Hurt: 92.89%
#   Fire: 99.04%
#   Destroy: 99.18%
#   Hurt: 75.26%
#   Destroy: 99.48%
#   Fire: 100.00%
#   Destroy: 99.92%
#   Destroy: 96.33%
#   Drop: 99.80%
#   Fire: 99.75%
#   Trampled: 88.25%
#   Drop: 99.37%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Destroy: 92.71%
#   Crash: 98.27%
#   Destroy: 75.82%
#   Violence: 98.36%
#   Crash: 99.89%
#   Fire: 99.91%
#   Fighting: 51.49%
#   Fire: 99.83%
#   Hurt: 91.69%
#   Thiefing: 100.00%
#   Crash: 45.31%
#   Fighting: 43.41%
#   Hurt: 78.63%
#   Trampled: 70.45%
#   Trampled: 99.88%
#   Destroy: 99.89%
#   Violence: 97.06%
#   Fire: 100.00%
#   Drop: 99.94%
#   Fighting: 93.67%
#   Trampled: 99.96%
#   Fire: 71.44%
#   Fighting: 48.18%
#   Fire: 100.00%
#   Destroy: 90.52%
#   Trampled: 99.93%
#   Drop: 99.93%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Violence: 90.32%
#   Fire: 100.00%
#   Violence: 93.86%
#   Fire: 100.00%
#   Drop: 99.74%
#   Violence: 96.82%
#   Destroy: 98.00%
#   Violence: 99.04%
#   Drop: 99.48%
#   Fighting: 84.59%
#   Crash: 65.98%
#   Fighting: 99.10%
#   Fire: 99.65%
#   Fire: 96.91%
#   Drop: 99.94%
#   Fire: 99.88%
#   Fire: 100.00%
#   Drop: 99.83%
#   Drop: 99.97%
#   Drop: 98.86%
#   Violence: 99.44%
#   Trampled: 99.73%
#   Crash: 99.74%
#   Hurt: 98.97%
#   Thiefing: 100.00%
#   Drop: 78.03%
#   Trampled: 98.00%
#   Crash: 99.74%
#   Crash: 99.71%
#   Fire: 99.96%
#   Fire: 100.00%
#   Trampled: 99.66%
#   Violence: 94.98%
#   Drop: 99.60%
#   Violence: 99.17%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Hurt: 61.22%
#   Crash: 99.39%
#   Fighting: 40.47%
#   Hurt: 62.42%
#   Violence: 57.35%
#   Destroy: 99.28%
#   Trampled: 99.97%
#   Fighting: 99.86%
#   Fire: 100.00%
#   Trampled: 97.56%
#   Drop: 90.50%
#   Hurt: 89.02%
#   Violence: 58.84%
#   Drop: 99.62%
#   Fighting: 99.83%
#   Hurt: 91.56%
#   Violence: 99.13%
#   Fighting: 68.88%
#   Crash: 99.07%
#   Hurt: 29.36%
#   Destroy: 99.94%
#   Thiefing: 100.00%
#   Destroy: 99.50%
#   Fire: 99.97%
#   Fighting: 99.82%
#   Destroy: 87.40%
#   Fire: 99.19%
#   Fire: 100.00%
#   Violence: 97.66%
#   Fire: 99.91%
#   Thiefing: 100.00%
#   Trampled: 73.33%
#   Fire: 100.00%
#   Hurt: 84.83%
#   Trampled: 50.33%
#   Fire: 99.87%
#   Thiefing: 99.96%
#   Crash: 97.74%
#   Drop: 99.72%
#   Trampled: 98.22%
#   Trampled: 97.94%
#   Crash: 99.78%
#   Trampled: 98.66%
#   Crash: 95.89%
#   Fire: 99.62%
#   Hurt: 96.80%
#   Fire: 100.00%
#   Fighting: 93.82%
#   Fire: 100.00%
#   Fighting: 98.51%
#   Hurt: 98.79%
#   Fire: 100.00%
#   Fighting: 98.41%
#   Drop: 99.63%
#   Trampled: 96.50%
#   Fire: 99.12%
#   Destroy: 83.50%
#   Drop: 99.66%
#   Violence: 97.55%
#   Thiefing: 99.99%
#   Trampled: 91.93%
#   Hurt: 83.38%
#   Violence: 48.46%
#   Destroy: 99.94%
#   Hurt: 99.70%
#   Destroy: 96.57%
#   Fighting: 91.55%
#   Fire: 99.76%
#   Fire: 99.79%
#   Violence: 72.12%
#   Violence: 86.07%
#   Destroy: 95.65%
#   Trampled: 99.89%
#   Thiefing: 99.79%
#   Fire: 100.00%
#   Crash: 99.84%
#   Destroy: 99.96%
#   Crash: 98.27%
#   Destroy: 94.90%
#   Crash: 79.72%
#   Thiefing: 72.21%
#   Thiefing: 99.98%
#   Violence: 98.96%
#   Thiefing: 100.00%
#   Drop: 99.88%
#   Hurt: 87.10%
#   Drop: 99.97%
#   Violence: 98.54%
#   Destroy: 67.34%
#   Destroy: 99.92%
#   Drop: 99.92%
#   Violence: 97.74%
#   Violence: 99.31%
#   Drop: 99.70%
#   Destroy: 98.79%
#   Fire: 99.90%
#   Fighting: 99.72%
#   Fighting: 99.66%
#   Trampled: 99.71%
#   Thiefing: 100.00%
#   Drop: 99.71%
#   Fire: 100.00%
#   Drop: 96.74%
#   Fire: 99.64%
#   Violence: 98.48%
#   Violence: 98.24%
#   Trampled: 99.34%
#   Drop: 71.58%
#   Destroy: 99.95%
#   Thiefing: 99.85%
#   Destroy: 99.56%
#   Fire: 100.00%
#   Fire: 100.00%
#   Hurt: 64.41%
#   Drop: 99.65%
#   Trampled: 99.95%
#   Fire: 100.00%
#   Crash: 99.80%
#   Fire: 100.00%
#   Violence: 53.16%
#   Destroy: 99.89%
#   Fire: 100.00%
#   Destroy: 97.81%
#   Fighting: 68.26%
#   Fire: 100.00%
#   Fire: 100.00%
#   Violence: 98.84%
#   Fighting: 99.82%
#   Fire: 99.90%
#   Fighting: 99.88%
#   Fire: 100.00%
#   Crash: 99.85%
#   Trampled: 99.58%
#   Fire: 99.82%
#   Violence: 98.58%
#   Destroy: 99.77%
#   Hurt: 97.23%
#   Trampled: 98.32%
#   Drop: 99.50%
#   Fire: 99.84%
#   Destroy: 99.18%
#   Fighting: 99.70%
#   Destroy: 99.98%
#   Hurt: 95.92%
#   Fire: 100.00%
#   Crash: 99.84%
#   Fire: 100.00%
#   Violence: 97.51%
#   Fighting: 99.74%
#   Fire: 99.81%
#   Drop: 99.90%
#   Violence: 42.57%
#   Thiefing: 99.93%
#   Violence: 94.39%
#   Fire: 100.00%
#   Destroy: 99.64%
#   Destroy: 98.87%
#   Fighting: 42.71%
#   Fire: 100.00%
#   Fire: 99.90%
#   Fire: 99.94%
#   Fire: 99.79%
#   Destroy: 99.99%
#   Fighting: 74.96%
#   Fire: 100.00%
#   Fire: 98.91%
#   Fire: 100.00%
#   Destroy: 92.61%
#   Destroy: 99.63%
#   Drop: 99.86%
#   Destroy: 99.84%
#   Drop: 99.95%
#   Hurt: 69.31%
#   Drop: 99.50%
#   Trampled: 63.74%
#   Fire: 100.00%
#   Violence: 94.15%
#   Destroy: 99.15%
#   Thiefing: 99.99%
#   Violence: 99.50%
#   Destroy: 98.97%
#   Fire: 100.00%
#   Destroy: 99.94%
#   Drop: 99.14%
#   Fire: 99.98%
#   Fire: 100.00%
#   Hurt: 67.62%
#   Fire: 100.00%
#   Drop: 91.39%
#   Crash: 65.03%
#   Thiefing: 99.99%
#   Fire: 99.85%
#   Fire: 100.00%
#   Fire: 100.00%
#   Violence: 90.23%
#   Fire: 100.00%
#   Destroy: 99.76%
#   Trampled: 85.79%
#   Fire: 99.87%
#   Fire: 99.90%
#   Trampled: 99.47%
#   Fire: 100.00%
#   Fire: 100.00%
#   Destroy: 99.93%
#   Violence: 96.68%
#   Fire: 99.23%
#   Thiefing: 100.00%
#   Destroy: 99.92%
#   Crash: 99.91%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Violence: 98.84%
#   Destroy: 99.98%
#   Fire: 99.98%
#   Hurt: 62.30%
#   Hurt: 51.79%
#   Trampled: 99.96%
#   Fighting: 60.90%
#   Trampled: 99.57%
#   Trampled: 99.80%
#   Destroy: 97.68%
#   Crash: 99.48%
#   Thiefing: 100.00%
#   Fighting: 91.44%
#   Violence: 98.26%
#   Fire: 100.00%
#   Fire: 99.94%
#   Violence: 90.73%
#   Destroy: 99.79%
#   Hurt: 93.02%
#   Fire: 100.00%
#   Fire: 100.00%
#   Violence: 69.25%
#   Drop: 99.73%
#   Fighting: 84.48%
#   Fire: 100.00%
#   Destroy: 99.69%
#   Violence: 97.61%
#   Fire: 100.00%
#   Trampled: 99.96%
#   Fire: 62.72%
#   Destroy: 99.97%
#   Trampled: 88.59%
#   Crash: 99.39%
#   Fire: 100.00%
#   Hurt: 90.40%
#   Hurt: 94.90%
#   Fire: 99.92%
#   Drop: 77.57%
#   Trampled: 98.04%
#   Fire: 100.00%
#   Fire: 100.00%
#   Destroy: 99.89%
#   Destroy: 98.72%
#   Violence: 90.03%
#   Fighting: 98.93%
#   Destroy: 99.90%
#   Trampled: 97.03%
#   Crash: 99.90%
#   Hurt: 99.54%
#   Fighting: 66.01%
#   Fire: 100.00%
# ...
#   Destroy: 99.97%
#   Fire: 100.00%
#   Destroy: 98.41%
#   Drop: 99.43%
#   Fire: 99.92%
#   Violence: 99.02%
#   Trampled: 99.66%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Crash: 98.75%
#   Thiefing: 100.00%
#   Trampled: 99.94%
#   Crash: 66.58%
#   Violence: 85.77%
#   Fire: 100.00%
#   Fire: 100.00%
#   Violence: 98.83%
#   Destroy: 99.98%
#   Drop: 97.92%
#   Drop: 99.86%
#   Violence: 99.09%
#   Destroy: 95.06%
#   Hurt: 94.69%
#   Hurt: 96.46%
#   Hurt: 67.41%
#   Fire: 100.00%
#   Fighting: 99.81%
#   Fire: 99.97%
#   Fighting: 81.05%
#   Destroy: 99.96%
#   Thiefing: 100.00%
#   Drop: 99.84%
#   Crash: 76.37%
#   Drop: 99.64%
#   Fighting: 99.76%
#   Fighting: 98.66%
#   Fire: 99.92%
#   Violence: 72.40%
#   Hurt: 98.38%
#   Fire: 100.00%
#   Fire: 99.72%
#   Fire: 100.00%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Violence: 96.85%
#   Destroy: 99.89%
#   Fire: 99.66%
#   Violence: 98.25%
#   Hurt: 74.37%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Trampled: 99.63%
#   Violence: 99.35%
#   Violence: 98.79%
#   Fire: 100.00%
#   Crash: 99.51%
#   Fire: 51.91%
#   Fighting: 99.13%
#   Drop: 99.19%
#   Thiefing: 99.92%
#   Fire: 100.00%
#   Crash: 98.62%
#   Crash: 99.71%
#   Destroy: 99.97%
#   Fire: 100.00%
#   Hurt: 99.20%
#   Drop: 99.30%
#   Violence: 86.93%
#   Destroy: 99.06%
#   Trampled: 99.91%
#   Hurt: 51.29%
#   Thiefing: 100.00%
#   Fighting: 67.65%
#   Trampled: 99.93%
#   Violence: 83.54%
#   Trampled: 99.73%
#   Fire: 100.00%
#   Drop: 99.92%
#   Fighting: 99.85%
#   Hurt: 55.07%
#   Trampled: 99.42%
#   Trampled: 99.79%
#   Fire: 100.00%
#   Fire: 100.00%
#   Violence: 76.30%
#   Fighting: 42.34%
#   Fire: 99.27%
#   Crash: 99.78%
#   Fire: 99.74%
#   Hurt: 61.39%
#   Destroy: 99.15%
#   Fire: 99.46%
#   Trampled: 51.96%
#   Fire: 100.00%
#   Crash: 99.84%
#   Drop: 99.97%
#   Trampled: 99.97%
#   Destroy: 99.88%
#   Fire: 99.45%
#   Crash: 98.11%
#   Drop: 99.88%
#   Fire: 100.00%
#   Trampled: 99.91%
#   Crash: 99.11%
#   Fighting: 71.92%
#   Hurt: 76.78%
#   Crash: 99.10%
#   Drop: 99.88%
#   Fighting: 99.71%
#   Trampled: 93.45%
#   Fighting: 99.10%
#   Fire: 99.84%
#   Destroy: 99.92%
#   Fire: 99.57%
#   Destroy: 99.60%
#   Fire: 100.00%
#   Drop: 99.68%
#   Thiefing: 99.46%
#   Fighting: 99.72%
#   Fighting: 99.66%
#   Drop: 99.95%
#   Violence: 98.55%
#   Crash: 94.10%
#   Hurt: 98.21%
#   Thiefing: 100.00%
#   Hurt: 45.38%
#   Fire: 99.66%
#   Hurt: 97.21%
#   Crash: 99.55%
#   Trampled: 99.94%
#   Drop: 99.79%
#   Drop: 52.28%
#   Hurt: 99.03%
#   Trampled: 84.60%
#   Crash: 99.23%
#   Fire: 100.00%
#   Crash: 99.68%
#   Destroy: 99.90%
#   Fighting: 99.83%
#   Crash: 99.02%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Drop: 99.96%
#   Trampled: 70.49%
#   Trampled: 93.38%
#   Fire: 99.68%
#   Destroy: 96.10%
#   Violence: 75.02%
#   Fighting: 99.79%
#   Fire: 100.00%
#   Drop: 98.73%
#   Fire: 100.00%
#   Hurt: 42.53%
#   Crash: 89.92%
#   Trampled: 99.77%
#   Thiefing: 100.00%
#   Drop: 99.89%
#   Trampled: 99.18%
#   Trampled: 97.80%
#   Destroy: 93.41%
#   Fighting: 77.53%
#   Violence: 99.47%
#   Destroy: 99.76%
#   Fighting: 97.26%
#   Thiefing: 88.92%
#   Thiefing: 80.11%
#   Fire: 99.88%
#   Fire: 100.00%
#   Thiefing: 99.98%
#   Fighting: 99.94%
#   Thiefing: 99.99%
#   Hurt: 99.34%
#   Drop: 99.89%
#   Fighting: 99.39%
#   Thiefing: 99.95%
#   Destroy: 99.62%
#   Fire: 98.49%
#   Drop: 99.60%
#   Trampled: 93.36%
#   Trampled: 99.43%
#   Fire: 99.74%
#   Drop: 99.65%
#   Destroy: 99.85%
#   Fire: 99.82%
#   Fire: 100.00%
#   Fire: 99.92%
#   Drop: 99.96%
#   Hurt: 45.74%
#   Fire: 99.80%
#   Destroy: 99.97%
#   Drop: 98.91%
#   Fire: 97.32%
#   Fighting: 99.81%
#   Violence: 98.87%
#   Violence: 98.96%
#   Drop: 99.94%
#   Fighting: 99.79%
#   Destroy: 42.00%
#   Thiefing: 100.00%
#   Drop: 98.83%
#   Destroy: 99.93%
#   Thiefing: 99.99%
#   Destroy: 99.87%
#   Thiefing: 66.09%
#   Destroy: 99.84%
#   Drop: 99.74%
#   Fire: 99.98%
#   Drop: 99.55%
#   Violence: 99.18%
#   Fire: 99.84%
#   Thiefing: 100.00%
#   Fighting: 95.02%
#   Drop: 99.93%
#   Destroy: 99.92%
#   Trampled: 99.96%
#   Violence: 95.27%
#   Trampled: 99.92%
#   Drop: 99.81%
#   Fighting: 99.02%
#   Crash: 95.50%
#   Fire: 100.00%
#   Fire: 99.82%
#   Destroy: 99.93%
#   Thiefing: 99.95%
#   Crash: 99.56%
#   Thiefing: 99.99%
#   Trampled: 89.28%
#   Fire: 98.57%
#   Hurt: 94.50%
#   Hurt: 88.62%
#   Fire: 100.00%
#   Fighting: 97.83%
#   Trampled: 98.02%
#   Fighting: 95.00%
#   Trampled: 99.82%
#   Fighting: 97.95%
#   Crash: 98.19%
#   Fire: 99.82%
#   Violence: 95.20%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Trampled: 99.82%
#   Fire: 100.00%
#   Trampled: 99.84%
#   Fighting: 98.79%
#   Destroy: 99.92%
#   Destroy: 99.29%
#   Trampled: 96.23%
#   Fire: 100.00%
#   Drop: 99.81%
#   Fire: 100.00%
#   Trampled: 99.98%
#   Destroy: 99.99%
#   Violence: 99.51%
#   Drop: 96.83%
#   Drop: 99.51%
#   Crash: 99.58%
#   Fire: 99.24%
#   Fire: 99.48%
#   Destroy: 94.82%
#   Crash: 99.92%
#   Fire: 99.86%
#   Fire: 99.81%
#   Violence: 73.43%
#   Fighting: 91.40%
#   Violence: 76.66%
#   Fighting: 82.56%
#   Fire: 100.00%
#   Fighting: 85.35%
#   Fire: 100.00%
#   Fighting: 94.76%
#   Violence: 93.57%
#   Fire: 99.96%
#   Destroy: 99.91%
#   Violence: 98.74%
#   Fire: 99.65%
#   Drop: 99.66%
#   Thiefing: 99.98%
#   Fire: 100.00%
#   Destroy: 99.97%
#   Destroy: 79.34%
#   Fire: 99.47%
#   Fighting: 99.94%
#   Fire: 99.65%
#   Fire: 100.00%
#   Fire: 95.44%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Fire: 100.00%
#   Hurt: 55.95%
#   Drop: 99.64%
#   Trampled: 88.55%
#   Violence: 82.86%
#   Fire: 100.00%
#   Hurt: 97.28%
#   Trampled: 99.97%
#   Thiefing: 99.99%
#   Violence: 99.21%
#   Fire: 100.00%
#   Destroy: 63.54%
#   Fire: 100.00%
#   Violence: 98.77%
#   Hurt: 79.46%
#   Hurt: 87.53%
#   Fire: 100.00%
#   Destroy: 98.98%
#   Trampled: 53.93%
#   Hurt: 91.57%
#   Thiefing: 99.98%
#   Destroy: 99.99%
#   Crash: 99.34%
#   Hurt: 71.67%
#   Fire: 100.00%
#   Violence: 97.22%
#   Drop: 99.55%
#   Drop: 99.46%
#   Destroy: 77.79%
#   Destroy: 99.52%
#   Destroy: 97.32%
#   Fighting: 99.74%
#   Thiefing: 99.98%
#   Hurt: 99.52%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Fighting: 98.17%
#   Violence: 92.53%
#   Drop: 99.67%
#   Violence: 99.18%
#   Thiefing: 100.00%
#   Violence: 96.02%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Violence: 90.69%
#   Thiefing: 99.97%
#   Violence: 51.52%
#   Crash: 96.66%
#   Thiefing: 99.99%
#   Violence: 94.07%
#   Thiefing: 100.00%
#   Drop: 99.83%
#   Violence: 98.04%
#   Fire: 100.00%
#   Fire: 100.00%
#   Hurt: 88.06%
#   Drop: 99.95%
#   Fire: 100.00%
#   Thiefing: 99.92%
#   Crash: 98.35%
#   Drop: 99.89%
#   Crash: 98.97%
#   Drop: 99.64%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Destroy: 99.98%
#   Drop: 99.91%
#   Trampled: 85.77%
#   Trampled: 99.98%
#   Hurt: 92.66%
#   Destroy: 99.86%
#   Fire: 100.00%
#   Drop: 99.92%
#   Trampled: 59.26%
#   Destroy: 99.94%
#   Thiefing: 99.92%
#   Thiefing: 99.85%
#   Drop: 99.72%
#   Trampled: 99.14%
#   Fire: 99.84%
#   Hurt: 97.98%
#   Violence: 98.67%
#   Fire: 99.95%
#   Fighting: 52.25%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Violence: 96.54%
#   Trampled: 99.24%
#   Violence: 37.85%
#   Fighting: 97.02%
#   Crash: 96.99%
#   Crash: 49.98%
#   Drop: 99.95%
#   Fighting: 90.88%
#   Trampled: 51.08%
#   Destroy: 99.90%
#   Fire: 100.00%
#   Fire: 99.98%
#   Fighting: 99.60%
#   Thiefing: 100.00%
#   Hurt: 98.08%
#   Fighting: 99.82%
#   Fire: 100.00%
#   Trampled: 99.89%
#   Hurt: 35.38%
#   Thiefing: 100.00%
#   Destroy: 99.86%
#   Drop: 99.32%
#   Thiefing: 100.00%
#   Hurt: 39.03%
#   Trampled: 79.05%
#   Crash: 99.02%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fighting: 74.35%
#   Fire: 99.82%
#   Fire: 99.91%
#   Fire: 99.50%
#   Fire: 99.19%
#   Fire: 99.65%
#   Fighting: 50.78%
#   Violence: 68.51%
#   Trampled: 99.87%
#   Hurt: 87.68%
#   Destroy: 99.91%
#   Trampled: 99.85%
#   Violence: 98.72%
#   Thiefing: 99.74%
#   Fighting: 99.54%
#   Destroy: 99.90%
#   Drop: 99.95%
#   Trampled: 99.64%
#   Destroy: 97.48%
#   Fighting: 54.73%
#   Trampled: 99.55%
#   Hurt: 96.42%
#   Hurt: 78.26%
#   Destroy: 99.37%
#   Thiefing: 99.99%
#   Fire: 98.04%
#   Trampled: 99.89%
#   Thiefing: 100.00%
#   Fighting: 49.98%
#   Fire: 99.64%
#   Trampled: 99.97%
#   Fire: 100.00%
#   Destroy: 66.21%
#   Fighting: 82.46%
#   Hurt: 99.43%
#   Trampled: 99.27%
#   Fighting: 87.20%
#   Violence: 69.68%
#   Destroy: 99.93%
#   Destroy: 98.55%
#   Destroy: 99.92%
#   Violence: 97.81%
#   Destroy: 99.95%
#   Hurt: 90.57%
#   Fire: 100.00%
#   Violence: 97.92%
#   Thiefing: 100.00%
#   Fighting: 49.84%
#   Trampled: 99.81%
#   Fire: 100.00%
#   Drop: 99.78%
#   Hurt: 66.66%
#   Destroy: 99.90%
#   Thiefing: 100.00%
#   Trampled: 99.65%
#   Drop: 99.91%
#   Fire: 100.00%
#   Fire: 100.00%
#   Trampled: 99.97%
#   Fire: 99.75%
#   Trampled: 97.63%
#   Drop: 99.16%
#   Thiefing: 99.98%
#   Destroy: 99.20%
#   Hurt: 72.57%
#   Destroy: 99.98%
#   Trampled: 99.71%
#   Fire: 100.00%
#   Fighting: 98.35%
#   Fire: 99.86%
#   Fire: 99.99%
#   Drop: 99.93%
#   Drop: 99.94%
#   Fire: 99.88%
#   Hurt: 68.87%
#   Hurt: 51.08%
#   Violence: 86.03%
#   Fighting: 99.86%
#   Hurt: 75.64%
#   Fighting: 95.61%
#   Crash: 98.51%
#   Hurt: 91.33%
#   Destroy: 92.39%
#   Destroy: 99.97%
#   Thiefing: 75.70%
#   Trampled: 99.94%
#   Fire: 97.35%
#   Fighting: 99.75%
#   Drop: 99.67%
#   Destroy: 99.98%
#   Destroy: 99.96%
#   Thiefing: 99.97%
#   Trampled: 61.00%
#   Trampled: 99.97%
#   Hurt: 64.43%
#   Fire: 100.00%
#   Fire: 85.22%
#   Destroy: 99.79%
#   Drop: 99.80%
#   Destroy: 90.27%
#   Drop: 99.97%
#   Fire: 98.60%
#   Fire: 100.00%
#   Trampled: 83.30%
#   Hurt: 82.12%
#   Fire: 99.80%
#   Violence: 97.71%
#   Crash: 99.29%
#   Fighting: 99.56%
#   Fighting: 96.84%
#   Trampled: 74.45%
#   Fire: 99.85%
#   Fire: 100.00%
#   Violence: 97.35%
#   Fire: 99.81%
#   Destroy: 99.95%
#   Fire: 99.15%
#   Fighting: 98.92%
#   Fire: 99.88%
#   Destroy: 99.74%
#   Drop: 96.27%
#   Trampled: 99.87%
#   Drop: 99.93%
#   Thiefing: 99.96%
#   Destroy: 99.97%
#   Violence: 71.92%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Trampled: 87.33%
#   Fire: 100.00%
#   Crash: 95.43%
#   Destroy: 86.58%
#   Hurt: 92.70%
#   Drop: 91.62%
#   Fire: 100.00%
#   Fire: 99.34%
#   Destroy: 99.97%
#   Trampled: 99.88%
#   Trampled: 84.93%
#   Thiefing: 99.43%
#   Thiefing: 99.99%
#   Fighting: 99.02%
#   Crash: 74.47%
#   Hurt: 99.56%
#   Hurt: 49.54%
#   Destroy: 99.34%
#   Drop: 99.95%
#   Fire: 100.00%
#   Drop: 99.94%
#   Fire: 98.20%
#   Fighting: 97.91%
#   Crash: 99.92%
#   Fighting: 90.72%
#   Violence: 99.28%
#   Hurt: 99.24%
#   Thiefing: 100.00%
#   Thiefing: 99.80%
#   Destroy: 98.69%
#   Fire: 99.93%
#   Thiefing: 100.00%
#   Fighting: 99.76%
#   Thiefing: 99.96%
#   Crash: 92.36%
#   Drop: 98.45%
#   Destroy: 97.82%
#   Fighting: 94.74%
#   Destroy: 99.32%
#   Fire: 100.00%
#   Violence: 93.35%
#   Destroy: 98.20%
#   Thiefing: 99.99%
#   Destroy: 99.89%
#   Hurt: 93.01%
#   Violence: 88.93%
#   Fire: 98.55%
#   Fire: 100.00%
#   Fighting: 99.36%
#   Trampled: 99.76%
#   Fire: 100.00%
#   Destroy: 99.42%
#   Fighting: 99.76%
#   Drop: 87.79%
#   Fire: 97.44%
#   Trampled: 99.93%
#   Destroy: 99.48%
#   Thiefing: 51.55%
#   Thiefing: 99.95%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Destroy: 97.37%
#   Fighting: 99.80%
#   Crash: 99.22%
#   Destroy: 99.90%
#   Hurt: 53.40%
#   Fire: 100.00%
#   Hurt: 96.17%
#   Drop: 99.66%
#   Violence: 99.42%
#   Fire: 99.38%
#   Fire: 100.00%
#   Drop: 97.34%
#   Destroy: 99.93%
#   Hurt: 87.87%
#   Trampled: 99.78%
#   Crash: 99.81%
#   Violence: 99.24%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Fighting: 99.84%
#   Trampled: 99.92%
#   Drop: 99.43%
#   Trampled: 98.23%
#   Trampled: 99.92%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Thiefing: 99.96%
#   Drop: 99.70%
#   Thiefing: 100.00%
#   Destroy: 72.03%
#   Trampled: 99.84%
#   Crash: 98.19%
#   Destroy: 98.15%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Fighting: 96.74%
#   Fire: 99.90%
#   Fire: 100.00%
#   Drop: 99.89%
#   Fire: 100.00%
#   Trampled: 98.88%
#   Destroy: 99.80%
#   Fire: 100.00%
#   Fighting: 96.45%
#   Fire: 99.92%
#   Drop: 99.92%
#   Fire: 97.40%
#   Destroy: 99.46%
#   Violence: 53.50%
#   Fire: 100.00%
#   Trampled: 99.87%
#   Fire: 100.00%
#   Destroy: 99.95%
#   Fire: 76.40%
#   Trampled: 91.88%
#   Violence: 92.37%
#   Violence: 63.97%
#   Violence: 95.75%
#   Fighting: 78.47%
#   Hurt: 89.10%
#   Violence: 72.61%
#   Hurt: 88.67%
#   Drop: 98.90%
#   Crash: 99.62%
#   Crash: 99.63%
#   Fighting: 87.96%
#   Crash: 96.13%
#   Fighting: 95.57%
#   Fire: 99.65%
#   Violence: 98.48%
#   Destroy: 99.39%
#   Violence: 98.88%
#   Destroy: 99.96%
#   Fighting: 99.56%
#   Thiefing: 99.97%
#   Fighting: 92.19%
#   Fire: 100.00%
#   Destroy: 99.90%
#   Drop: 99.95%
#   Thiefing: 100.00%
#   Hurt: 95.20%
#   Hurt: 71.05%
#   Destroy: 74.01%
#   Fighting: 99.95%
#   Fighting: 99.48%
#   Fire: 100.00%
#   Fighting: 97.67%
#   Drop: 99.96%
#   Destroy: 99.17%
#   Trampled: 99.84%
#   Fire: 99.93%
#   Destroy: 99.80%
#   Thiefing: 99.99%
#   Fire: 100.00%
#   Violence: 99.19%
#   Fire: 99.94%
#   Fighting: 92.12%
#   Fire: 99.80%
#   Fighting: 99.94%
#   Fire: 99.85%
#   Destroy: 52.65%
#   Fighting: 99.10%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Trampled: 44.37%
#   Crash: 99.81%
#   Trampled: 46.60%
#   Fire: 98.74%
#   Drop: 99.90%
#   Drop: 99.68%
#   Violence: 99.36%
#   Drop: 99.97%
#   Trampled: 97.63%
#   Fire: 99.96%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 100.00%
#   Violence: 72.63%
#   Hurt: 86.53%
#   Hurt: 80.51%
#   Destroy: 94.60%
#   Fire: 99.88%
#   Drop: 99.52%
#   Destroy: 90.63%
#   Drop: 99.66%
#   Drop: 99.81%
#   Fighting: 99.49%
#   Hurt: 52.10%
#   Violence: 99.43%
#   Fire: 100.00%
#   Thiefing: 99.97%
#   Drop: 99.91%
#   Violence: 97.88%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Violence: 98.83%
#   Fighting: 43.65%
#   Destroy: 65.75%
#   Thiefing: 100.00%
#   Trampled: 86.36%
#   Fighting: 95.44%
#   Hurt: 97.51%
#   Fighting: 99.69%
#   Fire: 100.00%
#   Destroy: 99.93%
#   Drop: 91.30%
#   Hurt: 86.45%
#   Hurt: 98.24%
#   Fire: 100.00%
#   Destroy: 99.96%
#   Destroy: 91.01%
#   Fire: 99.09%
#   Fighting: 99.61%
#   Crash: 99.78%
#   Fire: 100.00%
#   Trampled: 98.78%
#   Crash: 99.69%
#   Fighting: 96.09%
#   Fire: 100.00%
#   Drop: 99.97%
#   Fighting: 99.63%
#   Fighting: 98.48%
#   Thiefing: 99.90%
#   Fire: 99.64%
#   Drop: 99.91%
#   Thiefing: 99.99%
#   Fire: 99.99%
#   Fire: 100.00%
#   Violence: 66.11%
#   Thiefing: 100.00%
#   Violence: 96.46%
#   Crash: 95.87%
#   Fighting: 99.74%
#   Destroy: 53.08%
#   Thiefing: 100.00%
#   Hurt: 70.84%
#   Drop: 99.97%
#   Fighting: 95.81%
#   Violence: 64.49%
#   Violence: 98.87%
#   Crash: 99.74%
#   Thiefing: 100.00%
#   Drop: 99.66%
#   Violence: 98.33%
#   Fire: 100.00%
#   Hurt: 93.56%
#   Violence: 95.24%
#   Drop: 99.91%
#   Violence: 52.74%
#   Thiefing: 99.99%
#   Destroy: 98.82%
#   Thiefing: 100.00%
#   Violence: 99.25%
#   Destroy: 99.92%
#   Violence: 98.74%
#   Fire: 99.80%
#   Destroy: 99.90%
#   Destroy: 99.73%
#   Hurt: 98.50%
#   Violence: 99.30%
#   Trampled: 99.39%
#   Violence: 95.88%
#   Trampled: 73.96%
#   Fighting: 98.28%
#   Fighting: 75.61%
#   Fire: 99.97%
#   Thiefing: 100.00%
#   Fighting: 99.77%
#   Fighting: 97.45%
#   Fire: 100.00%
#   Thiefing: 99.99%
#   Thiefing: 100.00%
#   Fire: 100.00%
#   Fighting: 90.11%
#   Fire: 99.99%
#   Trampled: 99.90%
#   Fighting: 56.86%
#   Thiefing: 100.00%
#   Fighting: 99.14%
#   Thiefing: 99.96%
#   Fire: 99.50%
#   Drop: 99.85%
#   Hurt: 42.07%
#   Fire: 100.00%
#   Trampled: 79.62%
#   Crash: 99.77%
#   Drop: 99.89%
#   Hurt: 99.04%
#   Violence: 87.49%
#   Fire: 99.52%
#   Hurt: 99.27%
#   Fire: 99.57%
#   Trampled: 99.36%
#   Fire: 100.00%
#   Trampled: 88.09%
#   Hurt: 52.33%
#   Drop: 99.78%
#   Trampled: 96.30%
#   Thiefing: 99.87%
#   Hurt: 77.86%
#   Thiefing: 99.97%
#   Trampled: 99.97%
#   Crash: 99.22%
#   Trampled: 99.65%
#   Hurt: 99.04%
#   Fighting: 99.40%
#   Violence: 98.97%
#   Fire: 99.64%
#   Trampled: 99.69%
#   Fighting: 70.69%
#   Hurt: 54.60%
#   Fire: 100.00%
#   Fighting: 99.84%
#   Violence: 98.98%
#   Fighting: 96.94%
#   Violence: 89.49%
#   Trampled: 99.78%
#   Drop: 99.65%
#   Fire: 99.90%
#   Drop: 99.69%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Fire: 99.97%
#   Fire: 99.71%
#   Fire: 99.12%
#   Hurt: 89.97%
#   Violence: 99.14%
#   Fighting: 99.71%
#   Fire: 100.00%
#   Trampled: 99.94%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fire: 100.00%
#   Fighting: 99.74%
#   Crash: 99.55%
#   Destroy: 99.64%
#   Trampled: 99.78%
#   Violence: 99.25%
#   Trampled: 71.14%
#   Drop: 99.93%
#   Fighting: 95.11%
#   Fire: 100.00%
#   Fighting: 93.56%
#   Violence: 99.20%
#   Fire: 100.00%
#   Hurt: 65.13%
#   Trampled: 99.85%
#   Fighting: 99.85%
#   Fire: 99.84%
#   Destroy: 98.90%
#   Drop: 99.66%
#   Drop: 99.95%
#   Trampled: 50.49%
#   Fighting: 99.26%
#   Destroy: 99.97%
#   Thiefing: 100.00%
#   Thiefing: 100.00%
#   Violence: 96.25%
#   Fighting: 99.44%
#   Trampled: 98.68%
#   Destroy: 99.93%
#   Drop: 99.89%
#   Violence: 92.62%
#   Destroy: 99.95%
#   Drop: 99.95%
#   Crash: 99.21%
#   Destroy: 99.93%
#   Fighting: 99.80%
#   Drop: 99.64%
#   Fighting: 96.12%
#   Fire: 100.00%
#   Fire: 100.00%
#   Thiefing: 100.00%
#   Violence: 97.11%
#   Drop: 53.89%
#   Fire: 100.00%
#   Fighting: 99.66%
#   Fighting: 54.20%
#   Crash: 99.63%
#   Drop: 99.97%
#   Trampled: 99.38%
#   Thiefing: 99.99%
#   Fighting: 99.80%
#   Destroy: 99.93%
#   Fighting: 96.66%
#   Crash: 98.24%
#   Thiefing: 97.60%
#   Trampled: 99.86%
#   Crash: 99.82%

# %%
y_pred = np.array(y_pred)
y_pred, y_pred.shape
# Out:
# (array(['Thiefing', 'Drop', 'Violence', ..., 'Thiefing', 'Trampled',
#         'Crash'], dtype='<U8'),
#  (4407,))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
# cm = cm / cm.astype(np.float).sum(axis=1)

class_names = encoding

# Plot confusion matrix in a beautiful manner
fig = plt.figure(figsize=(16, 14))
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt = 'g'); #annot=True to annotate cells
# labels, title and ticks
ax.set_xlabel('Predicted', fontsize=20)
ax.xaxis.set_label_position('bottom')
plt.xticks(rotation=90)
ax.xaxis.set_ticklabels(class_names, fontsize = 10)
ax.xaxis.tick_bottom()

ax.set_ylabel('True', fontsize=20)
ax.yaxis.set_ticklabels(class_names, fontsize = 10)
plt.yticks(rotation=0)

plt.title('Confusion Matrix', fontsize=20)

plt.savefig('Models\\LAD_FROM_XDConMat_3000_94.08.png')
plt.show()

# %% [markdown]
# ---

# %%
model.trainable = False

# %%
frame_features_input = keras.Input((MAX_SEQ_LENGTH, NUM_FEATURES))
mask_input = keras.Input((MAX_SEQ_LENGTH,), dtype="bool")
x = model([frame_features_input, mask_input], training=False)
outputs = keras.layers.Dense(len(class_vocab), activation="softmax")(x)
model = keras.Model([frame_features_input, mask_input], outputs)
